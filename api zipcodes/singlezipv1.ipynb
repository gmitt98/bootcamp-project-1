# %%
# Dependencies
import requests
import json
from pprint import pprint
import pandas as pd

# Import the API key
from config import geoapify_key

# %%
zipcode = "97214"

params = {
    "apiKey": geoapify_key,
    "country":"United States",
    "postcode": zipcode
}
# Build URL using the geocode endpoint
base_url = f"https://api.geoapify.com/v1/geocode/search?text={zipcode}&lang=en&type=postcode&filter=countrycode:us"

# %%
#run request
response = requests.get(base_url, params=params).json()

print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "features": [
#         {
#             "geometry": {
#                 "coordinates": [
#                     -122.638582741,
#                     45.514217886
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Portland, OR 97214",
#                 "address_line2": "United States of America",
#                 "city": "Portland",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Multnomah County",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database License",
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "formatted": "Portland, OR 97214, United States of America",
#                 "lat": 45.514217886,
#                 "lon": -122.638582741,
#                 "place_id": "51a418258adea85ec059b2b145e4d1c14640f00101f901e97d750000000000c00207",
#                 "postcode": "97214",
#                 "rank": {
#                     "confidence": 1,
#                     "confidence_city_level": 1,
#                     "match_type": "full_match",
#                     "popularity": 4.889302687413859
#                 },
#                 "result_type": "postcode",
#                 "state": "Oregon",
#                 "state_code": "OR",
#                 "suburb": "Buckman",
#                 "timezone": {
#                     "abbreviation_DST": "PDT",
#                     "abbreviation_STD": "PST",
#                     "name": "America/Los_Angeles",
#                     "offset_DST": "-07:00",
#                     "offset_DST_seconds": -25200,
#                     "offset_STD": "-08:00",
#                     "offset_STD_seconds": -28800
#                 }
#             },
#             "type": "Feature"
#         }
#     ],
#     "query": {
#         "text": "97214"
#     },
#     "type": "FeatureCollection"
# }

# %%
 # Extract lat/lon
lat = response["features"][0]["properties"]["lat"]
lon = response["features"][0]["properties"]["lon"]
place_id = response["features"][0]["properties"]["place_id"]

# Print results
print(f"{zipcode}: {lat}, {lon}")
print(place_id)
# Out:
# 97214: 45.514217886, -122.638582741
# 51a418258adea85ec059b2b145e4d1c14640f00101f901e97d750000000000c00207

# %%
# Set paramaters for type of place
categories = "education.school"

# Set parameters for type of search
bias = f"proximity:{lon},{lat}"
filters = f"place:{place_id}"

# %%
#parameters dictionary
params = {
    "categories": categories,
    "bias": bias,
    "filters":filters,
    "apiKey": geoapify_key    
}

# %%
# Set base URL
base_url = f"https://api.geoapify.com/v2/places?"

# %%
response = requests.get(base_url, params=params).json()

# %%
pprint(response)
# Out:
# {'features': [{'geometry': {'coordinates': [-122.64040476786069,
#                                             45.52002442589504],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Central Catholic High School',
#                               'address_line2': '2401 Southeast Stark Street, '
#                                                'Portland, OR 97214, United '
#                                                'States of America',
#                               'categories': ['access_limited',
#                                              'access_limited.private',
#                                              'education',
#                                              'education.school'],
#                               'city': 'Portland',
#                               'country': 'United States',
#                               'country_code': 'us',
#                               'county': 'Multnomah County',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'access': 'private',
#                                                      'addr:city': 'Portland',
#                                                      'addr:housenumber': 2401,
#                                                      'addr:postcode': 97214,
#                                                      'addr:state': 'OR',
#                                                      'addr:street': 'Southeast '
#                                                                     'Stark '
#                                                                     'Street',
#                                                      'amenity': 'school',
#                                                      'denomination': 'catholic',
#                                                      'fax': '+1-503-233-0073',
#                                                      'max_age': 18,
#                                                      'min_age': 14,
#                                                      'name': 'Central Catholic '
#                                                              'High School',
#                                                      'osm_id': 39415140,
#                                                      'osm_type': 'w',
#                                                      'phone': '+1-503-235-3138',
#                                                      'religion': 'christian',
#                                                      'website': 'https://www.centralcatholichigh.org/',
#                                                      'wikidata': 'Q5060528',
#                                                      'wikipedia': 'en:Central '
#                                                                   'Catholic '
#                                                                   'High School '
#                                                                   '(Portland, '
#                                                                   'Oregon)'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details',
#                                           'details.contact',
#                                           'details.place_of_worship',
#                                           'details.restrictions',
#                                           'details.wiki_and_media'],
#                               'distance': 575,
#                               'formatted': 'Central Catholic High School, 2401 '
#                                            'Southeast Stark Street, Portland, '
#                                            'OR 97214, United States of America',
#                               'housenumber': '2401',
#                               'lat': 45.51998585,
#                               'lon': -122.64040122207228,
#                               'name': 'Central Catholic High School',
#                               'place_id': '51818a4764fca85ec059912b0f2990c24640f00102f901646d59020000000092031c43656e7472616c20436174686f6c69632048696768205363686f6f6c',
#                               'postcode': '97214',
#                               'state': 'Oregon',
#                               'state_code': 'OR',
#                               'street': 'Southeast Stark Street',
#                               'suburb': 'Buckman'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-122.63222220000002,
#                                             45.51055560041152],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Multnomah Early Childhood '
#                                                'Program',
#                               'address_line2': 'Southeast Market Street, '
#                                                'Portland, OR 97214, United '
#                                                'States of America',
#                               'categories': ['education', 'education.school'],
#                               'city': 'Portland',
#                               'country': 'United States',
#                               'country_code': 'us',
#                               'county': 'Multnomah County',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'addr:state': 'OR',
#                                                      'amenity': 'school',
#                                                      'ele': 46,
#                                                      'name': 'Multnomah Early '
#                                                              'Childhood '
#                                                              'Program',
#                                                      'osm_id': 357288095,
#                                                      'osm_type': 'n'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': [],
#                               'distance': 642,
#                               'district': 'Colonial Heights',
#                               'formatted': 'Multnomah Early Childhood Program, '
#                                            'Southeast Market Street, Portland, '
#                                            'OR 97214, United States of America',
#                               'lat': 45.5105556,
#                               'lon': -122.6322222,
#                               'name': 'Multnomah Early Childhood Program',
#                               'place_id': '5189331a5476a85ec0595047cbe259c14640f00103f9019fc84b15000000009203214d756c746e6f6d6168204561726c79204368696c64686f6f642050726f6772616d',
#                               'postcode': '97214',
#                               'state': 'Oregon',
#                               'state_code': 'OR',
#                               'street': 'Southeast Market Street',
#                               'suburb': 'Richmond'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-122.62896818827285,
#                                             45.51470079120277],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Sunnyside Environmental School',
#                               'address_line2': '3421 Southeast Salmon Street, '
#                                                'Portland, OR 97214, United '
#                                                'States of America',
#                               'categories': ['education',
#                                              'education.school',
#                                              'wheelchair',
#                                              'wheelchair.limited'],
#                               'city': 'Portland',
#                               'country': 'United States',
#                               'country_code': 'us',
#                               'county': 'Multnomah County',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'addr:city': 'Portland',
#                                                      'addr:housenumber': 3421,
#                                                      'addr:postcode': 97214,
#                                                      'addr:state': 'OR',
#                                                      'addr:street': 'Southeast '
#                                                                     'Salmon '
#                                                                     'Street',
#                                                      'amenity': 'school',
#                                                      'ele': 48,
#                                                      'grades': 'K-8',
#                                                      'name': 'Sunnyside '
#                                                              'Environmental '
#                                                              'School',
#                                                      'operator': 'Portland '
#                                                                  'Public '
#                                                                  'Schools',
#                                                      'operator:short': 'PPS',
#                                                      'operator:type': 'public',
#                                                      'operator:wikidata': 'Q608234',
#                                                      'operator:wikipedia': 'en:Portland '
#                                                                            'Public '
#                                                                            'Schools '
#                                                                            '(Oregon)',
#                                                      'osm_id': 32053153,
#                                                      'osm_type': 'w',
#                                                      'phone': '+1-503-916-6226',
#                                                      'website': 'https://www.pps.net/schools/sunnyside',
#                                                      'wheelchair': 'limited'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details',
#                                           'details.contact',
#                                           'details.facilities'],
#                               'distance': 710,
#                               'district': 'Belmont',
#                               'formatted': 'Sunnyside Environmental School, '
#                                            '3421 Southeast Salmon Street, '
#                                            'Portland, OR 97214, United States '
#                                            'of America',
#                               'housenumber': '3421',
#                               'lat': 45.51464645,
#                               'lon': -122.62891206341966,
#                               'name': 'Sunnyside Environmental School',
#                               'place_id': '51cdb6c90341a85ec0597ab82cb7e1c14640f00102f901a117e9010000000092031e53756e6e797369646520456e7669726f6e6d656e74616c205363686f6f6c',
#                               'postcode': '97214',
#                               'state': 'Oregon',
#                               'state_code': 'OR',
#                               'street': 'Southeast Salmon Street',
#                               'suburb': 'Sunnyside'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-122.63769251394676,
#                                             45.506096634569296],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Hosford Middle School',
#                               'address_line2': '2303 Southeast 28th Place, '
#                                                'Portland, OR 97214, United '
#                                                'States of America',
#                               'categories': ['education', 'education.school'],
#                               'city': 'Portland',
#                               'country': 'United States',
#                               'country_code': 'us',
#                               'county': 'Multnomah County',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'addr:city': 'Portland',
#                                                      'addr:housenumber': 2303,
#                                                      'addr:street': 'Southeast '
#                                                                     '28th '
#                                                                     'Place',
#                                                      'amenity': 'school',
#                                                      'fax': '+1-503-916-2637',
#                                                      'grades': '6-8',
#                                                      'name': 'Hosford Middle '
#                                                              'School',
#                                                      'operator': 'Portland '
#                                                                  'Public '
#                                                                  'Schools',
#                                                      'operator:short': 'PPS',
#                                                      'operator:type': 'public',
#                                                      'operator:wikidata': 'Q608234',
#                                                      'operator:wikipedia': 'en:Portland '
#                                                                            'Public '
#                                                                            'Schools '
#                                                                            '(Oregon)',
#                                                      'osm_id': 33294911,
#                                                      'osm_type': 'w',
#                                                      'phone': '+1-503-916-5640',
#                                                      'website': 'https://www.pps.net/schools/hosford'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details', 'details.contact'],
#                               'distance': 802,
#                               'district': 'Colonial Heights',
#                               'formatted': 'Hosford Middle School, 2303 '
#                                            'Southeast 28th Place, Portland, OR '
#                                            '97214, United States of America',
#                               'housenumber': '2303',
#                               'lat': 45.506184399999995,
#                               'lon': -122.6377072957217,
#                               'name': 'Hosford Middle School',
#                               'place_id': '518b1343f4cfa85ec0599f0b47c6c7c04640f00102f9013f0afc0100000000920315486f73666f7264204d6964646c65205363686f6f6c',
#                               'postcode': '97214',
#                               'state': 'Oregon',
#                               'state_code': 'OR',
#                               'street': 'Southeast 28th Place',
#                               'suburb': 'Hosford-Abernethy'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-122.64855972562779,
#                                             45.520043060557484],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Buckman Elementary School',
#                               'address_line2': '320 Southeast 16th Avenue, '
#                                                'Portland, OR 97214, United '
#                                                'States of America',
#                               'categories': ['education', 'education.school'],
#                               'city': 'Portland',
#                               'country': 'United States',
#                               'country_code': 'us',
#                               'county': 'Multnomah County',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'addr:city': 'Portland',
#                                                      'addr:housenumber': 320,
#                                                      'addr:street': 'Southeast '
#                                                                     '16th '
#                                                                     'Avenue',
#                                                      'amenity': 'school',
#                                                      'grades': 'K-5',
#                                                      'name': 'Buckman '
#                                                              'Elementary '
#                                                              'School',
#                                                      'operator': 'Portland '
#                                                                  'Public '
#                                                                  'Schools',
#                                                      'operator:short': 'PPS',
#                                                      'operator:type': 'public',
#                                                      'operator:wikidata': 'Q608234',
#                                                      'operator:wikipedia': 'en:Portland '
#                                                                            'Public '
#                                                                            'Schools '
#                                                                            '(Oregon)',
#                                                      'osm_id': 107484253,
#                                                      'osm_type': 'w',
#                                                      'phone': '+1 503 916 6230',
#                                                      'website': 'https://www.pps.net/schools/buckman'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details', 'details.contact'],
#                               'distance': 915,
#                               'formatted': 'Buckman Elementary School, 320 '
#                                            'Southeast 16th Avenue, Portland, '
#                                            'OR 97214, United States of America',
#                               'housenumber': '320',
#                               'lat': 45.52034355,
#                               'lon': -122.64855735584564,
#                               'name': 'Buckman Elementary School',
#                               'place_id': '51bec4a60082a95ec05996cd60c590c24640f00102f9015d146806000000009203194275636b6d616e20456c656d656e74617279205363686f6f6c',
#                               'postcode': '97214',
#                               'state': 'Oregon',
#                               'state_code': 'OR',
#                               'street': 'Southeast 16th Avenue',
#                               'suburb': 'Buckman'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-122.64459574127393,
#                                             45.522599265043944],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Le Monde French Immersion '
#                                                'Public Charter School',
#                               'address_line2': '2044 East Burnside Street, '
#                                                'Portland, OR 97214, United '
#                                                'States of America',
#                               'categories': ['building',
#                                              'building.school',
#                                              'education',
#                                              'education.school'],
#                               'city': 'Portland',
#                               'country': 'United States',
#                               'country_code': 'us',
#                               'county': 'Multnomah County',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'addr:city': 'Portland',
#                                                      'addr:housenumber': 2044,
#                                                      'addr:postcode': 97214,
#                                                      'addr:street': 'East '
#                                                                     'Burnside '
#                                                                     'Street',
#                                                      'amenity': 'school',
#                                                      'building': 'yes',
#                                                      'grades': 'K-8',
#                                                      'name': 'Le Monde French '
#                                                              'Immersion Public '
#                                                              'Charter School',
#                                                      'operator:type': 'private',
#                                                      'osm_id': 697667661,
#                                                      'osm_type': 'w',
#                                                      'phone': '+1 503 467 7529',
#                                                      'website': 'https://lemondeimmersion.org/'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details', 'details.contact'],
#                               'distance': 1028,
#                               'formatted': 'Le Monde French Immersion Public '
#                                            'Charter School, 2044 East Burnside '
#                                            'Street, Portland, OR 97214, United '
#                                            'States of America',
#                               'housenumber': '2044',
#                               'lat': 45.52260335,
#                               'lon': -122.64459161391542,
#                               'name': 'Le Monde French Immersion Public '
#                                       'Charter School',
#                               'place_id': '5165fa7e0e41a95ec05981236088e4c24640f00102f9014d9095290000000092032f4c65204d6f6e6465204672656e636820496d6d657273696f6e205075626c69632043686172746572205363686f6f6c',
#                               'postcode': '97214',
#                               'state': 'Oregon',
#                               'state_code': 'OR',
#                               'street': 'East Burnside Street',
#                               'suburb': 'Buckman'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-122.63991248779531,
#                                             45.52433236471515],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'da Vinci Arts Middle School',
#                               'address_line2': '2508 Northeast Davis Street, '
#                                                'Portland, OR 97232, United '
#                                                'States of America',
#                               'categories': ['education', 'education.school'],
#                               'city': 'Portland',
#                               'country': 'United States',
#                               'country_code': 'us',
#                               'county': 'Multnomah County',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'addr:city': 'Portland',
#                                                      'addr:housenumber': 2508,
#                                                      'addr:state': 'OR',
#                                                      'addr:street': 'Southeast '
#                                                                     'Everett '
#                                                                     'Street',
#                                                      'amenity': 'school',
#                                                      'ele': 42,
#                                                      'grades': '6-8',
#                                                      'name': 'da Vinci Arts '
#                                                              'Middle School',
#                                                      'operator': 'Portland '
#                                                                  'Public '
#                                                                  'Schools',
#                                                      'operator:short': 'PPS',
#                                                      'operator:type': 'public',
#                                                      'operator:wikidata': 'Q608234',
#                                                      'operator:wikipedia': 'en:Portland '
#                                                                            'Public '
#                                                                            'Schools '
#                                                                            '(Oregon)',
#                                                      'osm_id': 142986871,
#                                                      'osm_type': 'w',
#                                                      'phone': '+1 503 916 5356',
#                                                      'website': 'https://www.pps.net/schools/davinci',
#                                                      'wikidata': 'Q22582778'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details',
#                                           'details.contact',
#                                           'details.wiki_and_media'],
#                               'distance': 1050,
#                               'formatted': 'da Vinci Arts Middle School, 2508 '
#                                            'Northeast Davis Street, Portland, '
#                                            'OR 97232, United States of America',
#                               'housenumber': '2508',
#                               'lat': 45.5243003,
#                               'lon': -122.6398288837534,
#                               'name': 'da Vinci Arts Middle School',
#                               'place_id': '5181d88153f4a85ec059cc57ab521dc34640f00102f90177ce85080000000092031b64612056696e63692041727473204d6964646c65205363686f6f6c',
#                               'postcode': '97232',
#                               'state': 'Oregon',
#                               'state_code': 'OR',
#                               'street': 'Northeast Davis Street',
#                               'suburb': 'Kerns'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-122.63553915545262,
#                                             45.52405632897899],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Pacific Crest Community School',
#                               'address_line2': '116 Northeast 29th Avenue, '
#                                                'Portland, OR 97232, United '
#                                                'States of America',
#                               'categories': ['building',
#                                              'building.school',
#                                              'education',
#                                              'education.school',
#                                              'wheelchair',
#                                              'wheelchair.yes'],
#                               'city': 'Portland',
#                               'country': 'United States',
#                               'country_code': 'us',
#                               'county': 'Multnomah County',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'addr:city': 'Portland',
#                                                      'addr:housenumber': 116,
#                                                      'addr:postcode': 97232,
#                                                      'addr:street': 'Northeast '
#                                                                     '29th '
#                                                                     'Avenue',
#                                                      'amenity': 'school',
#                                                      'building': 'yes',
#                                                      'ele': 46,
#                                                      'name': 'Pacific Crest '
#                                                              'Community School',
#                                                      'osm_id': 107531026,
#                                                      'osm_type': 'w',
#                                                      'wheelchair': 'yes',
#                                                      'wikidata': 'Q14709183'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details.facilities',
#                                           'details.wiki_and_media'],
#                               'distance': 1101,
#                               'formatted': 'Pacific Crest Community School, '
#                                            '116 Northeast 29th Avenue, '
#                                            'Portland, OR 97232, United States '
#                                            'of America',
#                               'housenumber': '116',
#                               'lat': 45.524079,
#                               'lon': -122.6354891503509,
#                               'name': 'Pacific Crest Community School',
#                               'place_id': '51c6ff6bacaca85ec059011d1d4714c34640f00102f90112cb68060000000092031e5061636966696320437265737420436f6d6d756e697479205363686f6f6c',
#                               'postcode': '97232',
#                               'state': 'Oregon',
#                               'state_code': 'OR',
#                               'street': 'Northeast 29th Avenue',
#                               'suburb': 'Kerns'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-122.6517217403095,
#                                             45.50583119022301],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Abernethy Elementary School',
#                               'address_line2': 'Southeast Hickory Street, '
#                                                'Portland, OR 97214, United '
#                                                'States of America',
#                               'categories': ['education', 'education.school'],
#                               'city': 'Portland',
#                               'country': 'United States',
#                               'country_code': 'us',
#                               'county': 'Multnomah County',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'school',
#                                                      'fax': '+1-503-916-2600',
#                                                      'grades': 'K-5',
#                                                      'name': 'Abernethy '
#                                                              'Elementary '
#                                                              'School',
#                                                      'operator': 'Portland '
#                                                                  'Public '
#                                                                  'Schools',
#                                                      'operator:short': 'PPS',
#                                                      'operator:type': 'public',
#                                                      'operator:wikidata': 'Q608234',
#                                                      'operator:wikipedia': 'en:Portland '
#                                                                            'Public '
#                                                                            'Schools '
#                                                                            '(Oregon)',
#                                                      'osm_id': 134152018,
#                                                      'osm_type': 'w',
#                                                      'phone': '+1-503-916-6190',
#                                                      'website': 'https://www.pps.net/schools/abernethy'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details', 'details.contact'],
#                               'distance': 1288,
#                               'formatted': 'Abernethy Elementary School, '
#                                            'Southeast Hickory Street, '
#                                            'Portland, OR 97214, United States '
#                                            'of America',
#                               'lat': 45.50583015,
#                               'lon': -122.65172302941625,
#                               'name': 'Abernethy Elementary School',
#                               'place_id': '512d2e1acfb5a95ec059fda69113bfc04640f00102f90152fffe070000000092031b416265726e6574687920456c656d656e74617279205363686f6f6c',
#                               'postcode': '97214',
#                               'quarter': "Ladd's Addition",
#                               'state': 'Oregon',
#                               'state_code': 'OR',
#                               'street': 'Southeast Hickory Street',
#                               'suburb': 'Hosford-Abernethy'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-122.64303759999999,
#                                             45.52602080040955],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Kerr Youth Center at Wynne '
#                                                'Watts School',
#                               'address_line2': 'Northeast Flanders Street, '
#                                                'Portland, OR 97232, United '
#                                                'States of America',
#                               'categories': ['education', 'education.school'],
#                               'city': 'Portland',
#                               'country': 'United States',
#                               'country_code': 'us',
#                               'county': 'Multnomah County',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'addr:state': 'OR',
#                                                      'amenity': 'school',
#                                                      'ele': 44,
#                                                      'name': 'Kerr Youth '
#                                                              'Center at Wynne '
#                                                              'Watts School',
#                                                      'osm_id': 357363637,
#                                                      'osm_type': 'n',
#                                                      'website': 'https://www.albertinakerr.org/'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details'],
#                               'distance': 1357,
#                               'formatted': 'Kerr Youth Center at Wynne Watts '
#                                            'School, Northeast Flanders Street, '
#                                            'Portland, OR 97232, United States '
#                                            'of America',
#                               'lat': 45.5260208,
#                               'lon': -122.6430376,
#                               'name': 'Kerr Youth Center at Wynne Watts School',
#                               'place_id': '514a862d8727a95ec0592b634ba654c34640f00103f901b5ef4c15000000009203274b65727220596f7574682043656e7465722061742057796e6e65205761747473205363686f6f6c',
#                               'postcode': '97232',
#                               'state': 'Oregon',
#                               'state_code': 'OR',
#                               'street': 'Northeast Flanders Street',
#                               'suburb': 'Kerns'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-122.6187935518104,
#                                             45.511850885275315],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Attic Institute',
#                               'address_line2': '4232 Southeast Hawthorne '
#                                                'Boulevard, Portland, OR 97215, '
#                                                'United States of America',
#                               'categories': ['building',
#                                              'building.school',
#                                              'education',
#                                              'education.school'],
#                               'city': 'Portland',
#                               'country': 'United States',
#                               'country_code': 'us',
#                               'county': 'Multnomah County',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'addr:city': 'Portland',
#                                                      'addr:housenumber': 4232,
#                                                      'addr:postcode': 97215,
#                                                      'addr:state': 'OR',
#                                                      'addr:street': 'Southeast '
#                                                                     'Hawthorne '
#                                                                     'Boulevard',
#                                                      'amenity': 'school',
#                                                      'building': 'yes',
#                                                      'building:levels': 1,
#                                                      'description': 'A haven '
#                                                                     'for '
#                                                                     'writers.',
#                                                      'ele': 50.6,
#                                                      'height': 7.6,
#                                                      'name': 'Attic Institute',
#                                                      'osm_id': 369037815,
#                                                      'osm_type': 'w',
#                                                      'website': 'http://atticinstitute.com/'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details', 'details.building'],
#                               'distance': 1562,
#                               'formatted': 'Attic Institute, 4232 Southeast '
#                                            'Hawthorne Boulevard, Portland, OR '
#                                            '97215, United States of America',
#                               'housenumber': '4232',
#                               'lat': 45.511842,
#                               'lon': -122.61879387507257,
#                               'name': 'Attic Institute',
#                               'place_id': '51160045509aa75ec059d3576e5484c14640f00102f901f711ff150000000092030f417474696320496e73746974757465',
#                               'postcode': '97215',
#                               'state': 'Oregon',
#                               'state_code': 'OR',
#                               'street': 'Southeast Hawthorne Boulevard',
#                               'suburb': 'Richmond'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-122.61972968527627,
#                                             45.5063712459936],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Richmond Elementary School',
#                               'address_line2': '2276 Southeast 41st Avenue, '
#                                                'Portland, OR 97286, United '
#                                                'States of America',
#                               'categories': ['education', 'education.school'],
#                               'city': 'Portland',
#                               'country': 'United States',
#                               'country_code': 'us',
#                               'county': 'Multnomah County',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'addr:city': 'Portland',
#                                                      'addr:housenumber': 2276,
#                                                      'addr:state': 'OR',
#                                                      'addr:street': 'Southeast '
#                                                                     '41st '
#                                                                     'Avenue',
#                                                      'amenity': 'school',
#                                                      'ele': 48,
#                                                      'grades': 'PK-5',
#                                                      'name': 'Richmond '
#                                                              'Elementary '
#                                                              'School',
#                                                      'operator': 'Portland '
#                                                                  'Public '
#                                                                  'Schools',
#                                                      'operator:short': 'PPS',
#                                                      'operator:type': 'public',
#                                                      'operator:wikidata': 'Q608234',
#                                                      'operator:wikipedia': 'en:Portland '
#                                                                            'Public '
#                                                                            'Schools '
#                                                                            '(Oregon)',
#                                                      'osm_id': 33294951,
#                                                      'osm_type': 'w',
#                                                      'phone': '+1 503 916 6220',
#                                                      'website': 'https://www.pps.net/schools/richmond'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details', 'details.contact'],
#                               'distance': 1629,
#                               'formatted': 'Richmond Elementary School, 2276 '
#                                            'Southeast 41st Avenue, Portland, '
#                                            'OR 97286, United States of America',
#                               'housenumber': '2276',
#                               'lat': 45.5062351,
#                               'lon': -122.61972790717547,
#                               'name': 'Richmond Elementary School',
#                               'place_id': '51cea7b2a6a9a75ec059b196e2c5d0c04640f00102f901670afc010000000092031a526963686d6f6e6420456c656d656e74617279205363686f6f6c',
#                               'postcode': '97286',
#                               'state': 'Oregon',
#                               'state_code': 'OR',
#                               'street': 'Southeast 41st Avenue',
#                               'suburb': 'Richmond'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-122.65203271190772,
# ...
#                               'categories': ['education', 'education.school'],
#                               'city': 'Portland',
#                               'country': 'United States',
#                               'country_code': 'us',
#                               'county': 'Multnomah County',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'addr:city': 'Portland',
#                                                      'addr:housenumber': 840,
#                                                      'addr:postcode': 97232,
#                                                      'addr:state': 'OR',
#                                                      'addr:street': 'Northeast '
#                                                                     '41st '
#                                                                     'Avenue',
#                                                      'amenity': 'school',
#                                                      'ele': 62,
#                                                      'grades': 'K-8',
#                                                      'name': 'Laurelhurst '
#                                                              'School',
#                                                      'old_name': 'Laurelhurst '
#                                                                  'Elementary '
#                                                                  'School',
#                                                      'operator': 'Portland '
#                                                                  'Public '
#                                                                  'Schools',
#                                                      'operator:short': 'PPS',
#                                                      'operator:type': 'public',
#                                                      'operator:wikidata': 'Q608234',
#                                                      'operator:wikipedia': 'en:Portland '
#                                                                            'Public '
#                                                                            'Schools '
#                                                                            '(Oregon)',
#                                                      'osm_id': 142981975,
#                                                      'osm_type': 'w',
#                                                      'phone': '+1-503-916-6210',
#                                                      'website': 'https://www.pps.net/schools/laurelhurst'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details', 'details.contact'],
#                               'distance': 2135,
#                               'formatted': 'Laurelhurst School, 840 Northeast '
#                                            '41st Avenue, Portland, OR 97232, '
#                                            'United States of America',
#                               'housenumber': '840',
#                               'lat': 45.52917155,
#                               'lon': -122.61941520561032,
#                               'name': 'Laurelhurst School',
#                               'old_name': 'Laurelhurst Elementary School',
#                               'place_id': '51faa3dfeba3a75ec0594a6c9579bcc34640f00102f90157bb8508000000009203124c617572656c6875727374205363686f6f6c',
#                               'postcode': '97232',
#                               'state': 'Oregon',
#                               'state_code': 'OR',
#                               'street': 'Northeast 41st Avenue',
#                               'suburb': 'Laurelhurst'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-122.65094037585193,
#                                             45.49497011652433],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Winterhaven School',
#                               'address_line2': '3830 Southeast 14th Avenue, '
#                                                'Portland, OR 97202, United '
#                                                'States of America',
#                               'categories': ['education', 'education.school'],
#                               'city': 'Portland',
#                               'country': 'United States',
#                               'country_code': 'us',
#                               'county': 'Multnomah County',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'addr:city': 'Portland',
#                                                      'addr:housenumber': 3830,
#                                                      'addr:state': 'OR',
#                                                      'addr:street': 'Southeast '
#                                                                     '14th '
#                                                                     'Avenue',
#                                                      'amenity': 'school',
#                                                      'grades': 'K-8',
#                                                      'name': 'Winterhaven '
#                                                              'School',
#                                                      'operator': 'Portland '
#                                                                  'Public '
#                                                                  'Schools',
#                                                      'operator:short': 'PPS',
#                                                      'operator:type': 'public',
#                                                      'operator:wikidata': 'Q608234',
#                                                      'operator:wikipedia': 'en:Portland '
#                                                                            'Public '
#                                                                            'Schools '
#                                                                            '(Oregon)',
#                                                      'osm_id': 144950832,
#                                                      'osm_type': 'w',
#                                                      'phone': '+1 503 916 6200',
#                                                      'website': 'https://www.pps.net/schools/winterhaven'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details', 'details.contact'],
#                               'distance': 2294,
#                               'formatted': 'Winterhaven School, 3830 Southeast '
#                                            '14th Avenue, Portland, OR 97202, '
#                                            'United States of America',
#                               'housenumber': '3830',
#                               'lat': 45.4948993,
#                               'lon': -122.65104028298782,
#                               'name': 'Winterhaven School',
#                               'place_id': '51857bd201a9a95ec059127c472e5bbf4640f00102f90130c6a3080000000092031257696e746572686176656e205363686f6f6c',
#                               'postcode': '97202',
#                               'state': 'Oregon',
#                               'state_code': 'OR',
#                               'street': 'Southeast 14th Avenue',
#                               'suburb': 'Brooklyn'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-122.61231540089634,
#                                             45.52418870725622],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Gately Academy',
#                               'address_line2': '205 Northeast 50th Avenue, '
#                                                'Portland, OR 97215, United '
#                                                'States of America',
#                               'categories': ['building',
#                                              'building.school',
#                                              'education',
#                                              'education.school'],
#                               'city': 'Portland',
#                               'country': 'United States',
#                               'country_code': 'us',
#                               'county': 'Multnomah County',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'addr:city': 'Portland',
#                                                      'addr:housenumber': 205,
#                                                      'addr:street': 'Northeast '
#                                                                     '50th '
#                                                                     'Avenue',
#                                                      'amenity': 'school',
#                                                      'building': 'yes',
#                                                      'building:levels': 1,
#                                                      'ele': 56.3,
#                                                      'height': 6.5,
#                                                      'name': 'Gately Academy',
#                                                      'osm_id': 368522137,
#                                                      'osm_type': 'w'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details.building'],
#                               'distance': 2303,
#                               'formatted': 'Gately Academy, 205 Northeast 50th '
#                                            'Avenue, Portland, OR 97215, United '
#                                            'States of America',
#                               'housenumber': '205',
#                               'lat': 45.524230900000006,
#                               'lon': -122.61228989903267,
#                               'name': 'Gately Academy',
#                               'place_id': '51f66bef2c30a75ec0598b4c959d18c34640f00102f9019933f7150000000092030e476174656c792041636164656d79',
#                               'postcode': '97215',
#                               'state': 'Oregon',
#                               'state_code': 'OR',
#                               'street': 'Northeast 50th Avenue',
#                               'suburb': 'North Tabor'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-122.61757461521688,
#                                             45.498679503112484],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Saint Ignatius School',
#                               'address_line2': '3330 Southeast 43rd Avenue, '
#                                                'Portland, OR 97206, United '
#                                                'States of America',
#                               'categories': ['building',
#                                              'building.school',
#                                              'education',
#                                              'education.school'],
#                               'city': 'Portland',
#                               'country': 'United States',
#                               'country_code': 'us',
#                               'county': 'Multnomah County',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'addr:city': 'Portland',
#                                                      'addr:housenumber': 3330,
#                                                      'addr:postcode': 97206,
#                                                      'addr:state': 'OR',
#                                                      'addr:street': 'Southeast '
#                                                                     '43rd '
#                                                                     'Avenue',
#                                                      'amenity': 'school',
#                                                      'building': 'yes',
#                                                      'building:levels': 1,
#                                                      'denomination': 'catholic',
#                                                      'ele': 61.7,
#                                                      'height': 8.8,
#                                                      'max_age': 14,
#                                                      'min_age': 3,
#                                                      'name': 'Saint Ignatius '
#                                                              'School',
#                                                      'opening_hours': 'Mo-Fr '
#                                                                       '07:00-18:00',
#                                                      'osm_id': 369056493,
#                                                      'osm_type': 'w',
#                                                      'phone': '+1-503-774-5533',
#                                                      'religion': 'christian',
#                                                      'website': 'http://www.sispdx.org/'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details',
#                                           'details.building',
#                                           'details.contact',
#                                           'details.place_of_worship',
#                                           'details.restrictions'],
#                               'distance': 2326,
#                               'formatted': 'Saint Ignatius School, 3330 '
#                                            'Southeast 43rd Avenue, Portland, '
#                                            'OR 97206, United States of America',
#                               'housenumber': '3330',
#                               'lat': 45.498595949999995,
#                               'lon': -122.6181013074428,
#                               'name': 'Saint Ignatius School',
#                               'place_id': '5190ccad5786a75ec059de86debad4bf4640f00102f901ed5aff15000000009203155361696e742049676e6174697573205363686f6f6c',
#                               'postcode': '97206',
#                               'state': 'Oregon',
#                               'state_code': 'OR',
#                               'street': 'Southeast 43rd Avenue',
#                               'suburb': 'Richmond'},
#                'type': 'Feature'}],
#  'type': 'FeatureCollection'}

# %%
for feature in response["features"]:
    print(feature["properties"]["postcode"])
# Out:
# 97214
# 97214
# 97214
# 97214
# 97214
# 97214
# 97232
# 97232
# 97214
# 97232
# 97215
# 97286
# 97232
# 97202
# 97232
# 97215
# 97232
# 97202
# 97215
# 97206

# %%
# Extract the features list from the dictionary
features_list = response['features']

# Extract the relevant properties from each feature
rows = []
for feature in features_list:
    properties = feature['properties']
    rows.append(properties)

# Create a DataFrame from the list of dictionaries
df = pd.DataFrame(rows)
df
# Out:
#                                                name        country  \
# 0                      Central Catholic High School  United States
# 1                 Multnomah Early Childhood Program  United States
# 2                    Sunnyside Environmental School  United States
# 3                             Hosford Middle School  United States
# 4                         Buckman Elementary School  United States
# 5   Le Monde French Immersion Public Charter School  United States
# 6                       da Vinci Arts Middle School  United States
# 7                    Pacific Crest Community School  United States
# 8                       Abernethy Elementary School  United States
# 9           Kerr Youth Center at Wynne Watts School  United States
# 10                                  Attic Institute  United States
# 11                       Richmond Elementary School  United States
# 12                   Benson Polytechnic High School  United States
# 13                     Grover Cleveland High School  United States
# 14                       All Saints Catholic School  United States
# 15                        Glencoe Elementary School  United States
# 16                               Laurelhurst School  United States
# 17                               Winterhaven School  United States
# 18                                   Gately Academy  United States
# 19                            Saint Ignatius School  United States
#
#    country_code   state            county      city postcode  \
# 0            us  Oregon  Multnomah County  Portland    97214
# 1            us  Oregon  Multnomah County  Portland    97214
# 2            us  Oregon  Multnomah County  Portland    97214
# 3            us  Oregon  Multnomah County  Portland    97214
# 4            us  Oregon  Multnomah County  Portland    97214
# 5            us  Oregon  Multnomah County  Portland    97214
# 6            us  Oregon  Multnomah County  Portland    97232
# 7            us  Oregon  Multnomah County  Portland    97232
# 8            us  Oregon  Multnomah County  Portland    97214
# 9            us  Oregon  Multnomah County  Portland    97232
# 10           us  Oregon  Multnomah County  Portland    97215
# 11           us  Oregon  Multnomah County  Portland    97286
# 12           us  Oregon  Multnomah County  Portland    97232
# 13           us  Oregon  Multnomah County  Portland    97202
# 14           us  Oregon  Multnomah County  Portland    97232
# 15           us  Oregon  Multnomah County  Portland    97215
# 16           us  Oregon  Multnomah County  Portland    97232
# 17           us  Oregon  Multnomah County  Portland    97202
# 18           us  Oregon  Multnomah County  Portland    97215
# 19           us  Oregon  Multnomah County  Portland    97206
#
#                suburb                               street housenumber  ...  \
# 0             Buckman               Southeast Stark Street        2401  ...
# 1            Richmond              Southeast Market Street         NaN  ...
# 2           Sunnyside              Southeast Salmon Street        3421  ...
# 3   Hosford-Abernethy                 Southeast 28th Place        2303  ...
# 4             Buckman                Southeast 16th Avenue         320  ...
# 5             Buckman                 East Burnside Street        2044  ...
# 6               Kerns               Northeast Davis Street        2508  ...
# 7               Kerns                Northeast 29th Avenue         116  ...
# 8   Hosford-Abernethy             Southeast Hickory Street         NaN  ...
# 9               Kerns            Northeast Flanders Street         NaN  ...
# 10           Richmond        Southeast Hawthorne Boulevard        4232  ...
# 11           Richmond                Southeast 41st Avenue        2276  ...
# 12              Kerns                Northeast 12th Avenue         546  ...
# 13           Brooklyn                Southeast 26th Avenue        3400  ...
# 14        Laurelhurst  Northeast César E. Chávez Boulevard         601  ...
# 15        Mount Tabor                Southeast 51st Avenue         825  ...
# 16        Laurelhurst                Northeast 41st Avenue         840  ...
# 17           Brooklyn                Southeast 14th Avenue        3830  ...
# 18        North Tabor                Northeast 50th Avenue         205  ...
# 19           Richmond                Southeast 43rd Avenue        3330  ...
#
#                                       address_line1  \
# 0                      Central Catholic High School
# 1                 Multnomah Early Childhood Program
# 2                    Sunnyside Environmental School
# 3                             Hosford Middle School
# 4                         Buckman Elementary School
# 5   Le Monde French Immersion Public Charter School
# 6                       da Vinci Arts Middle School
# 7                    Pacific Crest Community School
# 8                       Abernethy Elementary School
# 9           Kerr Youth Center at Wynne Watts School
# 10                                  Attic Institute
# 11                       Richmond Elementary School
# 12                   Benson Polytechnic High School
# 13                     Grover Cleveland High School
# 14                       All Saints Catholic School
# 15                        Glencoe Elementary School
# 16                               Laurelhurst School
# 17                               Winterhaven School
# 18                                   Gately Academy
# 19                            Saint Ignatius School
#
#                                         address_line2  \
# 0   2401 Southeast Stark Street, Portland, OR 9721...
# 1   Southeast Market Street, Portland, OR 97214, U...
# 2   3421 Southeast Salmon Street, Portland, OR 972...
# 3   2303 Southeast 28th Place, Portland, OR 97214,...
# 4   320 Southeast 16th Avenue, Portland, OR 97214,...
# 5   2044 East Burnside Street, Portland, OR 97214,...
# 6   2508 Northeast Davis Street, Portland, OR 9723...
# 7   116 Northeast 29th Avenue, Portland, OR 97232,...
# 8   Southeast Hickory Street, Portland, OR 97214, ...
# 9   Northeast Flanders Street, Portland, OR 97232,...
# 10  4232 Southeast Hawthorne Boulevard, Portland, ...
# 11  2276 Southeast 41st Avenue, Portland, OR 97286...
# 12  546 Northeast 12th Avenue, Portland, OR 97232,...
# 13  3400 Southeast 26th Avenue, Portland, OR 97202...
# 14  601 Northeast César E. Chávez Boulevard, Portl...
# 15  825 Southeast 51st Avenue, Portland, OR 97215,...
# 16  840 Northeast 41st Avenue, Portland, OR 97232,...
# 17  3830 Southeast 14th Avenue, Portland, OR 97202...
# 18  205 Northeast 50th Avenue, Portland, OR 97215,...
# 19  3330 Southeast 43rd Avenue, Portland, OR 97206...
#
#                                            categories  \
# 0   [access_limited, access_limited.private, educa...
# 1                       [education, education.school]
# 2   [education, education.school, wheelchair, whee...
# 3                       [education, education.school]
# 4                       [education, education.school]
# 5   [building, building.school, education, educati...
# 6                       [education, education.school]
# 7   [building, building.school, education, educati...
# 8                       [education, education.school]
# 9                       [education, education.school]
# 10  [building, building.school, education, educati...
# 11                      [education, education.school]
# 12                      [education, education.school]
# 13                      [education, education.school]
# 14                      [education, education.school]
# 15                      [education, education.school]
# 16                      [education, education.school]
# 17                      [education, education.school]
# 18  [building, building.school, education, educati...
# 19  [building, building.school, education, educati...
#
#                                               details  \
# 0   [details, details.contact, details.place_of_wo...
# 1                                                  []
# 2      [details, details.contact, details.facilities]
# 3                          [details, details.contact]
# 4                          [details, details.contact]
# 5                          [details, details.contact]
# 6   [details, details.contact, details.wiki_and_me...
# 7        [details.facilities, details.wiki_and_media]
# 8                          [details, details.contact]
# 9                                           [details]
# 10                        [details, details.building]
# 11                         [details, details.contact]
# 12  [details, details.contact, details.wiki_and_me...
# 13  [details, details.contact, details.wiki_and_me...
# 14                                          [details]
# 15                         [details, details.contact]
# 16                         [details, details.contact]
# 17                         [details, details.contact]
# 18                                 [details.building]
# 19  [details, details.building, details.contact, d...
#
#                                            datasource distance  \
# 0   {'sourcename': 'openstreetmap', 'attribution':...      575
# 1   {'sourcename': 'openstreetmap', 'attribution':...      642
# 2   {'sourcename': 'openstreetmap', 'attribution':...      710
# 3   {'sourcename': 'openstreetmap', 'attribution':...      802
# 4   {'sourcename': 'openstreetmap', 'attribution':...      915
# 5   {'sourcename': 'openstreetmap', 'attribution':...     1028
# 6   {'sourcename': 'openstreetmap', 'attribution':...     1050
# 7   {'sourcename': 'openstreetmap', 'attribution':...     1101
# 8   {'sourcename': 'openstreetmap', 'attribution':...     1288
# 9   {'sourcename': 'openstreetmap', 'attribution':...     1357
# 10  {'sourcename': 'openstreetmap', 'attribution':...     1562
# 11  {'sourcename': 'openstreetmap', 'attribution':...     1629
# 12  {'sourcename': 'openstreetmap', 'attribution':...     1669
# 13  {'sourcename': 'openstreetmap', 'attribution':...     1689
# 14  {'sourcename': 'openstreetmap', 'attribution':...     1814
# 15  {'sourcename': 'openstreetmap', 'attribution':...     2056
# 16  {'sourcename': 'openstreetmap', 'attribution':...     2135
# 17  {'sourcename': 'openstreetmap', 'attribution':...     2294
# 18  {'sourcename': 'openstreetmap', 'attribution':...     2303
# 19  {'sourcename': 'openstreetmap', 'attribution':...     2326
#
#                                              place_id          district  \
# 0   51818a4764fca85ec059912b0f2990c24640f00102f901...               NaN
# 1   5189331a5476a85ec0595047cbe259c14640f00103f901...  Colonial Heights
# 2   51cdb6c90341a85ec0597ab82cb7e1c14640f00102f901...           Belmont
# 3   518b1343f4cfa85ec0599f0b47c6c7c04640f00102f901...  Colonial Heights
# 4   51bec4a60082a95ec05996cd60c590c24640f00102f901...               NaN
# 5   5165fa7e0e41a95ec05981236088e4c24640f00102f901...               NaN
# 6   5181d88153f4a85ec059cc57ab521dc34640f00102f901...               NaN
# 7   51c6ff6bacaca85ec059011d1d4714c34640f00102f901...               NaN
# 8   512d2e1acfb5a95ec059fda69113bfc04640f00102f901...               NaN
# 9   514a862d8727a95ec0592b634ba654c34640f00103f901...               NaN
# 10  51160045509aa75ec059d3576e5484c14640f00102f901...               NaN
# 11  51cea7b2a6a9a75ec059b196e2c5d0c04640f00102f901...               NaN
# 12  51376469e7baa95ec059555e86bc7cc34640f00102f901...               NaN
# 13  5156e979bddea85ec059b3d12fa7cebf4640f00102f901...               NaN
# 14  51f91ae49aeaa75ec05985ac69b880c34640f00102f901...               NaN
# 15  51742ea98122a75ec059eee2717e35c24640f00102f901...               NaN
# 16  51faa3dfeba3a75ec0594a6c9579bcc34640f00102f901...               NaN
# 17  51857bd201a9a95ec059127c472e5bbf4640f00102f901...               NaN
# 18  51f66bef2c30a75ec0598b4c959d18c34640f00102f901...               NaN
# 19  5190ccad5786a75ec059de86debad4bf4640f00102f901...               NaN
#
#             quarter                       old_name
# 0               NaN                            NaN
# 1               NaN                            NaN
# 2               NaN                            NaN
# 3               NaN                            NaN
# 4               NaN                            NaN
# 5               NaN                            NaN
# 6               NaN                            NaN
# 7               NaN                            NaN
# 8   Ladd's Addition                            NaN
# 9               NaN                            NaN
# 10              NaN                            NaN
# 11              NaN                            NaN
# 12              NaN                            NaN
# 13              NaN                            NaN
# 14              NaN                            NaN
# 15              NaN                            NaN
# 16              NaN  Laurelhurst Elementary School
# 17              NaN                            NaN
# 18              NaN                            NaN
# 19              NaN                            NaN
#
# [20 rows x 24 columns]

# %%
print(df.columns)
# Out:
# Index(['name', 'country', 'country_code', 'state', 'county', 'city',
#        'postcode', 'suburb', 'street', 'housenumber', 'lon', 'lat',
#        'state_code', 'formatted', 'address_line1', 'address_line2',
#        'categories', 'details', 'datasource', 'distance', 'place_id',
#        'district', 'quarter', 'old_name'],
#       dtype='object')

# %%
df = df.dropna(subset=['name', 'postcode'])
df = df.drop(columns=['country','country_code','state','street', 'state_code','formatted','address_line1',
                     'address_line2','categories','details','datasource','place_id','housenumber','district','suburb',
                      'quarter','old_name','city','hamlet'],errors='ignore')
df = df.rename(columns={
    'properties.postcode': 'zip_code',
    'properties.distance': 'distance',
})
df
# Out:
#                                                name            county  \
# 0                      Central Catholic High School  Multnomah County
# 1                 Multnomah Early Childhood Program  Multnomah County
# 2                    Sunnyside Environmental School  Multnomah County
# 3                             Hosford Middle School  Multnomah County
# 4                         Buckman Elementary School  Multnomah County
# 5   Le Monde French Immersion Public Charter School  Multnomah County
# 6                       da Vinci Arts Middle School  Multnomah County
# 7                    Pacific Crest Community School  Multnomah County
# 8                       Abernethy Elementary School  Multnomah County
# 9           Kerr Youth Center at Wynne Watts School  Multnomah County
# 10                                  Attic Institute  Multnomah County
# 11                       Richmond Elementary School  Multnomah County
# 12                   Benson Polytechnic High School  Multnomah County
# 13                     Grover Cleveland High School  Multnomah County
# 14                       All Saints Catholic School  Multnomah County
# 15                        Glencoe Elementary School  Multnomah County
# 16                               Laurelhurst School  Multnomah County
# 17                               Winterhaven School  Multnomah County
# 18                                   Gately Academy  Multnomah County
# 19                            Saint Ignatius School  Multnomah County
#
#    postcode         lon        lat  distance
# 0     97214 -122.640401  45.519986       575
# 1     97214 -122.632222  45.510556       642
# 2     97214 -122.628912  45.514646       710
# 3     97214 -122.637707  45.506184       802
# 4     97214 -122.648557  45.520344       915
# 5     97214 -122.644592  45.522603      1028
# 6     97232 -122.639829  45.524300      1050
# 7     97232 -122.635489  45.524079      1101
# 8     97214 -122.651723  45.505830      1288
# 9     97232 -122.643038  45.526021      1357
# 10    97215 -122.618794  45.511842      1562
# 11    97286 -122.619728  45.506235      1629
# 12    97232 -122.652034  45.527245      1669
# 13    97202 -122.638617  45.498541      1689
# 14    97232 -122.623773  45.527431      1814
# 15    97215 -122.611530  45.517042      2056
# 16    97232 -122.619415  45.529172      2135
# 17    97202 -122.651040  45.494899      2294
# 18    97215 -122.612290  45.524231      2303
# 19    97206 -122.618101  45.498596      2326
