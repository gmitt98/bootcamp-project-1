# %%
# Dependencies
import requests
import json
from pprint import pprint
import pandas as pd

# Import the API key
from config import geoapify_key

# %%
zipcode = "90049"

params = {
    "apiKey": geoapify_key,
    "country":"United States",
    "postcode": zipcode
}
# Build URL using the geocode endpoint
base_url = f"https://api.geoapify.com/v1/geocode/search?text={zipcode}&lang=en&type=postcode&filter=countrycode:us"

# %%
#run request
response = requests.get(base_url, params=params).json()

print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "features": [
#         {
#             "geometry": {
#                 "coordinates": [
#                     -118.469933765,
#                     34.07755113
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Los Angeles County, CA 90049",
#                 "address_line2": "United States of America",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Los Angeles County",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database License",
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "formatted": "Los Angeles County, CA 90049, United States of America",
#                 "lat": 34.07755113,
#                 "lon": -118.469933765,
#                 "parent_as_place_id": true,
#                 "place_id": "5183fd1165139e5dc059168f0732ed094140f00101f901bf0c060000000000c00207",
#                 "postcode": "90049",
#                 "rank": {
#                     "confidence": 1,
#                     "confidence_city_level": 1,
#                     "match_type": "full_match",
#                     "popularity": 5.063176304076575
#                 },
#                 "result_type": "postcode",
#                 "state": "California",
#                 "state_code": "CA",
#                 "timezone": {
#                     "abbreviation_DST": "PDT",
#                     "abbreviation_STD": "PST",
#                     "name": "America/Los_Angeles",
#                     "offset_DST": "-07:00",
#                     "offset_DST_seconds": -25200,
#                     "offset_STD": "-08:00",
#                     "offset_STD_seconds": -28800
#                 }
#             },
#             "type": "Feature"
#         }
#     ],
#     "query": {
#         "text": "90049"
#     },
#     "type": "FeatureCollection"
# }

# %%
 # Extract lat/lon
lat = response["features"][0]["properties"]["lat"]
lon = response["features"][0]["properties"]["lon"]
place_id = response["features"][0]["properties"]["place_id"]

# Print results
print(f"{zipcode}: {lat}, {lon}")
print(place_id)
# Out:
# 90049: 34.07755113, -118.469933765
# 5183fd1165139e5dc059168f0732ed094140f00101f901bf0c060000000000c00207

# %%
# Set paramaters for type of place
categories = "education.school"

# Set parameters for type of search
bias = f"proximity:{lon},{lat}"
filters = f"place:{place_id}"

# %%
#parameters dictionary
params = {
    "categories": categories,
    "bias": bias,
    "filter": filters,
    "apiKey": geoapify_key    
}

# %%
# Set base URL
base_url = f"https://api.geoapify.com/v2/places?filter=place:{place_id}"

# %%
response = requests.get(base_url, params=params).json()

# %%
pprint(response)
# Out:
# {'features': [{'geometry': {'coordinates': [-118.46280302313586,
#                                             34.08313583525082],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Bellagio Road',
#                               'address_line2': 'Los Angeles County, CA 90049, '
#                                                'United States of America',
#                               'categories': ['education', 'education.school'],
#                               'country': 'United States',
#                               'country_code': 'us',
#                               'county': 'Los Angeles County',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'school',
#                                                      'osm_id': 648203786,
#                                                      'osm_type': 'w'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': [],
#                               'distance': 769,
#                               'formatted': 'Bellagio Road, Los Angeles County, '
#                                            'CA 90049, United States of America',
#                               'lat': 34.08326785,
#                               'lon': -118.4628394279338,
#                               'place_id': '51f13692909e9d5dc05993c3ee31a40a4140f00102f9010acea22600000000',
#                               'postcode': '90049',
#                               'state': 'California',
#                               'state_code': 'CA',
#                               'street': 'Bellagio Road'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-118.46246199999997,
#                                             34.08211319960447],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Bellagio Newcomer Center',
#                               'address_line2': 'Bellagio Road, Los Angeles '
#                                                'County, CA 90049, United '
#                                                'States of America',
#                               'categories': ['education', 'education.school'],
#                               'country': 'United States',
#                               'country_code': 'us',
#                               'county': 'Los Angeles County',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'school',
#                                                      'ele': 218,
#                                                      'name': 'Bellagio '
#                                                              'Newcomer Center',
#                                                      'osm_id': 358780538,
#                                                      'osm_type': 'n'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': [],
#                               'distance': 855,
#                               'formatted': 'Bellagio Newcomer Center, Bellagio '
#                                            'Road, Los Angeles County, CA '
#                                            '90049, United States of America',
#                               'lat': 34.0821132,
#                               'lon': -118.462462,
#                               'name': 'Bellagio Newcomer Center',
#                               'place_id': '51216937fa989d5dc059816f71af820a4140f00103f9017a8e62150000000092031842656c6c6167696f204e6577636f6d65722043656e746572',
#                               'postcode': '90049',
#                               'state': 'California',
#                               'state_code': 'CA',
#                               'street': 'Bellagio Road'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-118.46891013947365,
#                                             34.06707931059845],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Brentwood School East Campus',
#                               'address_line2': 'South Barrington Place, '
#                                                'Brentwood, CA 90049, United '
#                                                'States of America',
#                               'categories': ['education', 'education.school'],
#                               'country': 'United States',
#                               'country_code': 'us',
#                               'county': 'Los Angeles County',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'school',
#                                                      'name': 'Brentwood School '
#                                                              'East Campus',
#                                                      'name:old': 'Brentwood '
#                                                                  'Military '
#                                                                  'Academy',
#                                                      'osm_id': 260232616,
#                                                      'osm_type': 'w'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': [],
#                               'distance': 1074,
#                               'district': 'Brentwood Heights',
#                               'formatted': 'Brentwood School East Campus, '
#                                            'South Barrington Place, Brentwood, '
#                                            'CA 90049, United States of America',
#                               'lat': 34.06683285,
#                               'lon': -118.4690353169037,
#                               'name': 'Brentwood School East Campus',
#                               'place_id': '515673ac9f029e5dc05919a10a0e96084140f00102f901a8d5820f0000000092031c4272656e74776f6f64205363686f6f6c20456173742043616d707573',
#                               'postcode': '90049',
#                               'state': 'California',
#                               'state_code': 'CA',
#                               'street': 'South Barrington Place',
#                               'suburb': 'Brentwood'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-118.46350909771749,
#                                             34.08730109828569],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Linda Flora Drive',
#                               'address_line2': 'Los Angeles County, CA 90049, '
#                                                'United States of America',
#                               'categories': ['education', 'education.school'],
#                               'country': 'United States',
#                               'country_code': 'us',
#                               'county': 'Los Angeles County',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'school',
#                                                      'osm_id': 648457797,
#                                                      'osm_type': 'w'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': [],
#                               'distance': 1105,
#                               'formatted': 'Linda Flora Drive, Los Angeles '
#                                            'County, CA 90049, United States of '
#                                            'America',
#                               'lat': 34.08716285,
#                               'lon': -118.46342091813791,
#                               'place_id': '5116061022aa9d5dc0595e05b1ae2c0b4140f00102f90145aea62600000000',
#                               'postcode': '90049',
#                               'state': 'California',
#                               'state_code': 'CA',
#                               'street': 'Linda Flora Drive'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-118.46661640189761,
#                                             34.06553718430716],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Brentwood School Athletic '
#                                                'Facilities VA lease',
#                               'address_line2': 'South Barrington Place, '
#                                                'Brentwood, CA 90049, United '
#                                                'States of America',
#                               'categories': ['education', 'education.school'],
#                               'country': 'United States',
#                               'country_code': 'us',
#                               'county': 'Los Angeles County',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'school',
#                                                      'name': 'Brentwood School '
#                                                              'Athletic '
#                                                              'Facilities VA '
#                                                              'lease',
#                                                      'osm_id': 807705249,
#                                                      'osm_type': 'w'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': [],
#                               'distance': 1129,
#                               'district': 'Brentwood Heights',
#                               'formatted': 'Brentwood School Athletic '
#                                            'Facilities VA lease, South '
#                                            'Barrington Place, Brentwood, CA '
#                                            '90049, United States of America',
#                               'lat': 34.0652654,
#                               'lon': -118.46685196634343,
#                               'name': 'Brentwood School Athletic Facilities VA '
#                                       'lease',
#                               'place_id': '515b7b0a0bdd9d5dc059b6a2bf8563084140f00102f901a19a24300000000092032d4272656e74776f6f64205363686f6f6c204174686c6574696320466163696c6974696573205641206c65617365',
#                               'postcode': '90049',
#                               'state': 'California',
#                               'state_code': 'CA',
#                               'street': 'South Barrington Place',
#                               'suburb': 'Brentwood'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-118.4634176, 34.08746209960466],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'The John Thomas Dye School',
#                               'address_line2': 'Chalon Road, Los Angeles '
#                                                'County, CA 90049, United '
#                                                'States of America',
#                               'categories': ['education', 'education.school'],
#                               'country': 'United States',
#                               'country_code': 'us',
#                               'county': 'Los Angeles County',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'school',
#                                                      'ele': 285,
#                                                      'name': 'The John Thomas '
#                                                              'Dye School',
#                                                      'osm_id': 358783249,
#                                                      'osm_type': 'n',
#                                                      'website': 'http://www.jtdschool.com/'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details'],
#                               'distance': 1253,
#                               'formatted': 'The John Thomas Dye School, Chalon '
#                                            'Road, Los Angeles County, CA '
#                                            '90049, United States of America',
#                               'lat': 34.0874621,
#                               'lon': -118.4634176,
#                               'name': 'The John Thomas Dye School',
#                               'place_id': '5103194ba2a89d5dc05983b844f5310b4140f00103f901119962150000000092031a546865204a6f686e2054686f6d617320447965205363686f6f6c',
#                               'postcode': '90049',
#                               'state': 'California',
#                               'state_code': 'CA',
#                               'street': 'Chalon Road'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-118.4823105, 34.085296599604575],
#                             'type': 'Point'},
#                'properties': {'address_line1': "Mount Saint Mary's College - "
#                                                'Chalon Campus',
#                               'address_line2': 'Grace Lane, Los Angeles '
#                                                'County, CA 90049, United '
#                                                'States of America',
#                               'categories': ['education', 'education.school'],
#                               'country': 'United States',
#                               'country_code': 'us',
#                               'county': 'Los Angeles County',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'school',
#                                                      'ele': 329,
#                                                      'name': 'Mount Saint '
#                                                              "Mary's College - "
#                                                              'Chalon Campus',
#                                                      'osm_id': 358789501,
#                                                      'osm_type': 'n'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': [],
#                               'distance': 1429,
#                               'formatted': "Mount Saint Mary's College - "
#                                            'Chalon Campus, Grace Lane, Los '
#                                            'Angeles County, CA 90049, United '
#                                            'States of America',
#                               'lat': 34.0852966,
#                               'lon': -118.4823105,
#                               'name': "Mount Saint Mary's College - Chalon "
#                                       'Campus',
#                               'place_id': '511d01dc2cde9e5dc0597ee1bcffea0a4140f00103f9017db162150000000092032a4d6f756e74205361696e74204d617279277320436f6c6c656765202d204368616c6f6e2043616d707573',
#                               'postcode': '90049',
#                               'state': 'California',
#                               'state_code': 'CA',
#                               'street': 'Grace Lane'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-118.473809, 34.06240209960378],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Saint Martin of Tours School',
#                               'address_line2': 'Sunset Boulevard, Brentwood, '
#                                                'CA 90049, United States of '
#                                                'America',
#                               'categories': ['education', 'education.school'],
#                               'country': 'United States',
#                               'country_code': 'us',
#                               'county': 'Los Angeles County',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'school',
#                                                      'ele': 141,
#                                                      'name': 'Saint Martin of '
#                                                              'Tours School',
#                                                      'osm_id': 358791830,
#                                                      'osm_type': 'n'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': [],
#                               'distance': 1718,
#                               'district': 'Brentwood Heights',
#                               'formatted': 'Saint Martin of Tours School, '
#                                            'Sunset Boulevard, Brentwood, CA '
#                                            '90049, United States of America',
#                               'lat': 34.0624021,
#                               'lon': -118.473809,
#                               'name': 'Saint Martin of Tours School',
#                               'place_id': '513be3fbe2529e5dc059ff7fc0cafc074140f00103f90196ba62150000000092031c5361696e74204d617274696e206f6620546f757273205363686f6f6c',
#                               'postcode': '90049',
#                               'state': 'California',
#                               'state_code': 'CA',
#                               'street': 'Sunset Boulevard',
#                               'suburb': 'Brentwood'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-118.48902011745332,
#                                             34.07054073826368],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Kenter Canyon Elementary '
#                                                'School',
#                               'address_line2': 'Elkins Road, Los Angeles '
#                                                'County, CA 90272, United '
#                                                'States of America',
#                               'categories': ['education', 'education.school'],
#                               'country': 'United States',
#                               'country_code': 'us',
#                               'county': 'Los Angeles County',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'school',
#                                                      'name': 'Kenter Canyon '
#                                                              'Elementary '
#                                                              'School',
#                                                      'osm_id': 58577047,
#                                                      'osm_type': 'w'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': [],
#                               'distance': 1851,
#                               'formatted': 'Kenter Canyon Elementary School, '
#                                            'Elkins Road, Los Angeles County, '
#                                            'CA 90272, United States of America',
#                               'lat': 34.070640499999996,
#                               'lon': -118.48923251971365,
#                               'name': 'Kenter Canyon Elementary School',
#                               'place_id': '5114e3081b4c9f5dc05969f0997a07094140f00102f90197d07d030000000092031f4b656e7465722043616e796f6e20456c656d656e74617279205363686f6f6c',
#                               'postcode': '90272',
#                               'state': 'California',
#                               'state_code': 'CA',
#                               'street': 'Elkins Road'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-118.47535829999997,
#                                             34.06111999960373],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Marymount Junior School',
#                               'address_line2': 'Sunset Boulevard, Brentwood, '
#                                                'CA 90272, United States of '
#                                                'America',
#                               'categories': ['education', 'education.school'],
#                               'country': 'United States',
#                               'country_code': 'us',
#                               'county': 'Los Angeles County',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'school',
#                                                      'ele': 133,
#                                                      'name': 'Marymount Junior '
#                                                              'School',
#                                                      'osm_id': 358788756,
#                                                      'osm_type': 'n'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': [],
#                               'distance': 1890,
#                               'district': 'Brentwood Heights',
#                               'formatted': 'Marymount Junior School, Sunset '
#                                            'Boulevard, Brentwood, CA 90272, '
#                                            'United States of America',
#                               'lat': 34.06112,
#                               'lon': -118.4753583,
#                               'name': 'Marymount Junior School',
#                               'place_id': '51731838456c9e5dc059fcb6b7c7d2074140f00103f90194ae6215000000009203174d6172796d6f756e74204a756e696f72205363686f6f6c',
#                               'postcode': '90272',
#                               'state': 'California',
#                               'state_code': 'CA',
#                               'street': 'Sunset Boulevard',
#                               'suburb': 'Brentwood'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-118.44527198807725,
#                                             34.07539207355002],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Marymount Place',
#                               'address_line2': 'Westwood, CA 90095, United '
#                                                'States of America',
#                               'categories': ['education', 'education.school'],
#                               'country': 'United States',
#                               'country_code': 'us',
#                               'county': 'Los Angeles County',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'school',
#                                                      'osm_id': 648203780,
#                                                      'osm_type': 'w'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': [],
#                               'distance': 2221,
#                               'formatted': 'Marymount Place, Westwood, CA '
#                                            '90095, United States of America',
#                               'lat': 34.07487195,
#                               'lon': -118.44531508922995,
#                               'place_id': '5178a714567f9c5dc05932238d72a6094140f00102f90104cea22600000000',
#                               'postcode': '90095',
#                               'quarter': 'Bel Air',
#                               'state': 'California',
#                               'state_code': 'CA',
#                               'street': 'Marymount Place',
#                               'suburb': 'Westwood'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-118.44531040691173,
#                                             34.075082908483026],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Marymount High School',
#                               'address_line2': '10643 West Sunset Boulevard, '
#                                                'Westwood, CA 90077, United '
#                                                'States of America',
#                               'categories': ['building',
#                                              'building.school',
#                                              'education',
#                                              'education.school'],
#                               'country': 'United States',
#                               'country_code': 'us',
#                               'county': 'Los Angeles County',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'addr:housenumber': 10643,
#                                                      'addr:postcode': 90077,
#                                                      'addr:street': 'Sunset '
#                                                                     'Boulevard',
#                                                      'amenity': 'school',
#                                                      'building': 'yes',
#                                                      'ele': 150.8,
#                                                      'height': 14.3,
#                                                      'lacounty:ain': 4362009001,
#                                                      'lacounty:bld_id': 426825850073,
#                                                      'name': 'Marymount High '
#                                                              'School',
#                                                      'osm_id': 232235624,
#                                                      'osm_type': 'w',
#                                                      'website': 'https://www.mhs-la.org/',
#                                                      'wikidata': 'Q6781626',
#                                                      'wikipedia': 'en:Marymount '
#                                                                   'High '
#                                                                   'School'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details',
#                                           'details.building',
#                                           'details.wiki_and_media'],
#                               'distance': 2273,
#                               'formatted': 'Marymount High School, 10643 West '
#                                            'Sunset Boulevard, Westwood, CA '
#                                            '90077, United States of America',
#                               'housenumber': '10643',
#                               'lat': 34.07495735,
#                               'lon': -118.44540795656403,
#                               'name': 'Marymount High School',
#                               'place_id': '51479038f77f9c5dc0592a3616519c094140f00102f90168a2d70d000000009203154d6172796d6f756e742048696768205363686f6f6c',
#                               'postcode': '90077',
#                               'state': 'California',
#                               'state_code': 'CA',
#                               'street': 'West Sunset Boulevard',
#                               'suburb': 'Westwood'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-118.44370468781229,
#                                             34.07555720479568],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'UCLA Lab School',
#                               'address_line2': 'Marymount Place, Westwood, CA '
#                                                '90095, United States of '
#                                                'America',
#                               'categories': ['education', 'education.school'],
#                               'country': 'United States',
#                               'country_code': 'us',
#                               'county': 'Los Angeles County',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'school',
#                                                      'name': 'UCLA Lab School',
#                                                      'old_name': 'Corinne A. '
#                                                                  'Seeds '
#                                                                  'University '
#                                                                  'Elementary '
#                                                                  'School',
#                                                      'osm_id': 810618013,
#                                                      'osm_type': 'w',
#                                                      'website': 'https://www.labschool.ucla.edu/',
#                                                      'wikidata': 'Q7864033',
#                                                      'wikipedia': 'en:UCLA Lab '
#                                                                   'School'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details', 'details.wiki_and_media'],
#                               'distance': 2372,
#                               'formatted': 'UCLA Lab School, Marymount Place, '
#                                            'Westwood, CA 90095, United States '
#                                            'of America',
#                               'lat': 34.075407850000005,
#                               'lon': -118.44370074885704,
#                               'name': 'UCLA Lab School',
#                               'old_name': 'Corinne A. Seeds University '
#                                           'Elementary School',
#                               'place_id': '5115cf58a8659c5dc0598dc9c5dbab094140f00102f9019d0c51300000000092030f55434c41204c6162205363686f6f6c',
#                               'postcode': '90095',
#                               'quarter': 'Bel Air',
#                               'state': 'California',
#                               'state_code': 'CA',
#                               'street': 'Marymount Place',
#                               'suburb': 'Westwood'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-118.47419498918288,
#                                             34.05084839682899],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Brentwood Science Magnet '
#                                                'School',
#                               'address_line2': 'Montana Avenue, Brentwood, CA '
#                                                '90073, United States of '
#                                                'America',
#                               'categories': ['education', 'education.school'],
#                               'country': 'United States',
#                               'country_code': 'us',
#                               'county': 'Los Angeles County',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'school',
#                                                      'ele': 92,
#                                                      'name': 'Brentwood '
#                                                              'Science Magnet '
#                                                              'School',
#                                                      'operator': 'Los Angeles '
#                                                                  'Unified '
#                                                                  'School '
#                                                                  'District',
#                                                      'operator:short': 'LAUSD',
#                                                      'operator:type': 'public',
#                                                      'operator:wikidata': 'Q1320340',
#                                                      'osm_id': 1112838174,
#                                                      'osm_type': 'w'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details'],
#                               'distance': 2881,
#                               'district': 'Westgate',
#                               'formatted': 'Brentwood Science Magnet School, '
#                                            'Montana Avenue, Brentwood, CA '
#                                            '90073, United States of America',
#                               'lat': 34.0506447,
#                               'lon': -118.47394030984486,
#                               'name': 'Brentwood Science Magnet School',
#                               'place_id': '51ec9df035599e5dc0599fb7443382064140f00102f9011e9054420000000092031f4272656e74776f6f6420536369656e6365204d61676e6574205363686f6f6c',
#                               'postcode': '90073',
#                               'state': 'California',
#                               'state_code': 'CA',
#                               'street': 'Montana Avenue',
#                               'suburb': 'Brentwood'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-118.49452539999997,
#                                             34.05528659960353],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Revere Middle School',
#                               'address_line2': 'Allenford Avenue, Los Angeles '
#                                                'County, CA 90272, United '
#                                                'States of America',
#                               'categories': ['education', 'education.school'],
#                               'country': 'United States',
#                               'country_code': 'us',
#                               'county': 'Los Angeles County',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'school',
#                                                      'ele': 109,
#                                                      'name': 'Revere Middle '
#                                                              'School',
#                                                      'osm_id': 358791089,
#                                                      'osm_type': 'n'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': [],
#                               'distance': 3355,
#                               'district': 'Brentwood Park',
#                               'formatted': 'Revere Middle School, Allenford '
#                                            'Avenue, Los Angeles County, CA '
#                                            '90272, United States of America',
#                               'lat': 34.0552866,
#                               'lon': -118.4945254,
#                               'name': 'Revere Middle School',
#                               'place_id': '51a302dd4da69f5dc059239a9ca113074140f00103f901b1b7621500000000920314526576657265204d6964646c65205363686f6f6c',
#                               'postcode': '90272',
#                               'state': 'California',
#                               'state_code': 'CA',
#                               'street': 'Allenford Avenue'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-118.43377395395446,
#                                             34.06950596960253],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Warner Elementary School',
#                               'address_line2': 'Woodruff Avenue, Westwood, CA '
#                                                '90095, United States of '
#                                                'America',
#                               'categories': ['education', 'education.school'],
#                               'country': 'United States',
#                               'country_code': 'us',
#                               'county': 'Los Angeles County',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'school',
#                                                      'ele': 111,
#                                                      'name': 'Warner '
#                                                              'Elementary '
#                                                              'School',
#                                                      'osm_id': 55639773,
#                                                      'osm_type': 'w'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': [],
#                               'distance': 3365,
#                               'district': 'Holmby Hills',
#                               'formatted': 'Warner Elementary School, Woodruff '
#                                            'Avenue, Westwood, CA 90095, United '
#                                            'States of America',
#                               'lat': 34.069455500000004,
#                               'lon': -118.4338187452514,
#                               'name': 'Warner Elementary School',
#                               'place_id': '51d385d4f3c29b5dc059ea285592e5084140f00102f901ddfe5003000000009203185761726e657220456c656d656e74617279205363686f6f6c',
#                               'postcode': '90095',
#                               'state': 'California',
#                               'state_code': 'CA',
#                               'street': 'Woodruff Avenue',
#                               'suburb': 'Westwood'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-118.43378644823326,
#                                             34.08855387864152],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Harvard-Westlake Middle School',
#                               'address_line2': 'Angelo Drive, Beverly Hills, '
#                                                'CA 90077, United States of '
#                                                'America',
#                               'categories': ['education', 'education.school'],
#                               'city': 'Beverly Hills',
#                               'country': 'United States',
#                               'country_code': 'us',
#                               'county': 'Los Angeles County',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'school',
#                                                      'ele': 171,
#                                                      'name': 'Harvard-Westlake '
#                                                              'Middle School',
#                                                      'osm_id': 388762654,
#                                                      'osm_type': 'w'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': [],
#                               'distance': 3450,
#                               'formatted': 'Harvard-Westlake Middle School, '
#                                            'Angelo Drive, Beverly Hills, CA '
#                                            '90077, United States of America',
#                               'lat': 34.0885181,
#                               'lon': -118.43388964858883,
#                               'name': 'Harvard-Westlake Middle School',
#                               'place_id': '5108273c28c39b5dc0598259c6bb550b4140f00102f9011e0c2c170000000092031e486172766172642d576573746c616b65204d6964646c65205363686f6f6c',
#                               'postcode': '90077',
#                               'state': 'California',
#                               'state_code': 'CA',
#                               'street': 'Angelo Drive'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-118.45954661119606,
#                                             34.045121829989256],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'University High School',
#                               'address_line2': 'Texas Avenue, Sawtelle, CA '
#                                                '90073, United States of '
#                                                'America',
#                               'categories': ['education', 'education.school'],
#                               'country': 'United States',
#                               'country_code': 'us',
#                               'county': 'Los Angeles County',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'school',
#                                                      'ele': 74,
#                                                      'name': 'University High '
#                                                              'School',
#                                                      'operator': 'Los Angeles '
#                                                                  'Unified '
#                                                                  'School '
#                                                                  'District',
#                                                      'operator:short': 'LAUSD',
#                                                      'operator:type': 'public',
#                                                      'operator:wikidata': 'Q1320340',
#                                                      'operator:wikipedia': 'en:Los '
#                                                                            'Angeles '
#                                                                            'Unified '
#                                                                            'School '
#                                                                            'District',
#                                                      'osm_id': 1009167955,
#                                                      'osm_type': 'w'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details'],
#                               'distance': 3528,
#                               'formatted': 'University High School, Texas '
#                                            'Avenue, Sawtelle, CA 90073, United '
#                                            'States of America',
#                               'lat': 34.045325399999996,
#                               'lon': -118.46000855919704,
#                               'name': 'University High School',
#                               'place_id': '51c8843036699d5dc059dc11588dc6054140f00102f90153ae263c00000000920316556e69766572736974792048696768205363686f6f6c',
#                               'postcode': '90073',
#                               'state': 'California',
#                               'state_code': 'CA',
#                               'street': 'Texas Avenue',
#                               'suburb': 'Sawtelle'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-118.45526363013688,
#                                             34.04694179706579],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Saint Sebastian School',
#                               'address_line2': 'Federal Avenue, Sawtelle, CA '
#                                                '90064, United States of '
#                                                'America',
#                               'categories': ['education', 'education.school'],
#                               'country': 'United States',
#                               'country_code': 'us',
#                               'county': 'Los Angeles County',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'school',
#                                                      'denomination': 'catholic',
#                                                      'ele': 70,
#                                                      'name': 'Saint Sebastian '
#                                                              'School',
#                                                      'osm_id': 253095069,
#                                                      'osm_type': 'w',
#                                                      'religion': 'christian'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details.place_of_worship'],
#                               'distance': 3617,
#                               'formatted': 'Saint Sebastian School, Federal '
#                                            'Avenue, Sawtelle, CA 90064, United '
#                                            'States of America',
#                               'lat': 34.0467171,
#                               'lon': -118.45532505072913,
#                               'name': 'Saint Sebastian School',
#                               'place_id': '51c19f100a239d5dc059459b553002064140f00102f9019dec150f000000009203165361696e742053656261737469616e205363686f6f6c',
#                               'postcode': '90064',
#                               'state': 'California',
#                               'state_code': 'CA',
#                               'street': 'Federal Avenue',
#                               'suburb': 'Sawtelle'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-118.46286002838787,
#                                             34.04410004586598],
#                             'type': 'Point'},
#                'properties': {'address_line1': 'Brockton Avenue Elementary '
#                                                'School',
#                               'address_line2': 'Rochester Avenue, Sawtelle, CA '
#                                                '90025, United States of '
#                                                'America',
#                               'categories': ['education', 'education.school'],
#                               'country': 'United States',
#                               'country_code': 'us',
#                               'county': 'Los Angeles County',
#                               'datasource': {'attribution': '© OpenStreetMap '
#                                                             'contributors',
#                                              'license': 'Open Database Licence',
#                                              'raw': {'amenity': 'school',
#                                                      'name': 'Brockton Avenue '
#                                                              'Elementary '
#                                                              'School',
#                                                      'operator': 'Los Angeles '
#                                                                  'Unified '
#                                                                  'School '
#                                                                  'District',
#                                                      'operator:short': 'LAUSD',
#                                                      'operator:type': 'public',
#                                                      'operator:wikidata': 'Q1320340',
#                                                      'operator:wikipedia': 'en:Los '
#                                                                            'Angeles '
#                                                                            'Unified '
#                                                                            'School '
#                                                                            'District',
#                                                      'osm_id': 220407171,
#                                                      'osm_type': 'w'},
#                                              'sourcename': 'openstreetmap',
#                                              'url': 'https://www.openstreetmap.org/copyright'},
#                               'details': ['details'],
#                               'distance': 3692,
#                               'formatted': 'Brockton Avenue Elementary School, '
#                                            'Rochester Avenue, Sawtelle, CA '
#                                            '90025, United States of America',
#                               'lat': 34.0440361,
#                               'lon': -118.46280560376249,
#                               'name': 'Brockton Avenue Elementary School',
#                               'place_id': '514c23ab7f9f9d5dc0598d5fff11a5054140f00102f9018325230d0000000092032142726f636b746f6e204176656e756520456c656d656e74617279205363686f6f6c',
#                               'postcode': '90025',
#                               'state': 'California',
#                               'state_code': 'CA',
#                               'street': 'Rochester Avenue',
#                               'suburb': 'Sawtelle'},
#                'type': 'Feature'}],
#  'type': 'FeatureCollection'}

# %%
for feature in response["features"]:
    print(feature["properties"]["postcode"])
# Out:
# 90049
# 90049
# 90049
# 90049
# 90049
# 90049
# 90049
# 90049
# 90272
# 90272
# 90095
# 90077
# 90095
# 90073
# 90272
# 90095
# 90077
# 90073
# 90064
# 90025

# %%
# Extract the features list from the dictionary
features_list = response['features']

# Extract the relevant properties from each feature
rows = []
for feature in features_list:
    properties = feature['properties']
    rows.append(properties)

# Create a DataFrame from the list of dictionaries
df = pd.DataFrame(rows)
df
# Out:
#           country country_code       state              county postcode  \
# 0   United States           us  California  Los Angeles County    90049
# 1   United States           us  California  Los Angeles County    90049
# 2   United States           us  California  Los Angeles County    90049
# 3   United States           us  California  Los Angeles County    90049
# 4   United States           us  California  Los Angeles County    90049
# 5   United States           us  California  Los Angeles County    90049
# 6   United States           us  California  Los Angeles County    90049
# 7   United States           us  California  Los Angeles County    90049
# 8   United States           us  California  Los Angeles County    90272
# 9   United States           us  California  Los Angeles County    90272
# 10  United States           us  California  Los Angeles County    90095
# 11  United States           us  California  Los Angeles County    90077
# 12  United States           us  California  Los Angeles County    90095
# 13  United States           us  California  Los Angeles County    90073
# 14  United States           us  California  Los Angeles County    90272
# 15  United States           us  California  Los Angeles County    90095
# 16  United States           us  California  Los Angeles County    90077
# 17  United States           us  California  Los Angeles County    90073
# 18  United States           us  California  Los Angeles County    90064
# 19  United States           us  California  Los Angeles County    90025
#
#                     street         lon        lat state_code  \
# 0            Bellagio Road -118.462839  34.083268         CA
# 1            Bellagio Road -118.462462  34.082113         CA
# 2   South Barrington Place -118.469035  34.066833         CA
# 3        Linda Flora Drive -118.463421  34.087163         CA
# 4   South Barrington Place -118.466852  34.065265         CA
# 5              Chalon Road -118.463418  34.087462         CA
# 6               Grace Lane -118.482310  34.085297         CA
# 7         Sunset Boulevard -118.473809  34.062402         CA
# 8              Elkins Road -118.489233  34.070640         CA
# 9         Sunset Boulevard -118.475358  34.061120         CA
# 10         Marymount Place -118.445315  34.074872         CA
# 11   West Sunset Boulevard -118.445408  34.074957         CA
# 12         Marymount Place -118.443701  34.075408         CA
# 13          Montana Avenue -118.473940  34.050645         CA
# 14        Allenford Avenue -118.494525  34.055287         CA
# 15         Woodruff Avenue -118.433819  34.069456         CA
# 16            Angelo Drive -118.433890  34.088518         CA
# 17            Texas Avenue -118.460009  34.045325         CA
# 18          Federal Avenue -118.455325  34.046717         CA
# 19        Rochester Avenue -118.462806  34.044036         CA
#
#                                             formatted  ...  \
# 0   Bellagio Road, Los Angeles County, CA 90049, U...  ...
# 1   Bellagio Newcomer Center, Bellagio Road, Los A...  ...
# 2   Brentwood School East Campus, South Barrington...  ...
# 3   Linda Flora Drive, Los Angeles County, CA 9004...  ...
# 4   Brentwood School Athletic Facilities VA lease,...  ...
# 5   The John Thomas Dye School, Chalon Road, Los A...  ...
# 6   Mount Saint Mary's College - Chalon Campus, Gr...  ...
# 7   Saint Martin of Tours School, Sunset Boulevard...  ...
# 8   Kenter Canyon Elementary School, Elkins Road, ...  ...
# 9   Marymount Junior School, Sunset Boulevard, Bre...  ...
# 10  Marymount Place, Westwood, CA 90095, United St...  ...
# 11  Marymount High School, 10643 West Sunset Boule...  ...
# 12  UCLA Lab School, Marymount Place, Westwood, CA...  ...
# 13  Brentwood Science Magnet School, Montana Avenu...  ...
# 14  Revere Middle School, Allenford Avenue, Los An...  ...
# 15  Warner Elementary School, Woodruff Avenue, Wes...  ...
# 16  Harvard-Westlake Middle School, Angelo Drive, ...  ...
# 17  University High School, Texas Avenue, Sawtelle...  ...
# 18  Saint Sebastian School, Federal Avenue, Sawtel...  ...
# 19  Brockton Avenue Elementary School, Rochester A...  ...
#
#                                            datasource distance  \
# 0   {'sourcename': 'openstreetmap', 'attribution':...      769
# 1   {'sourcename': 'openstreetmap', 'attribution':...      855
# 2   {'sourcename': 'openstreetmap', 'attribution':...     1074
# 3   {'sourcename': 'openstreetmap', 'attribution':...     1105
# 4   {'sourcename': 'openstreetmap', 'attribution':...     1129
# 5   {'sourcename': 'openstreetmap', 'attribution':...     1253
# 6   {'sourcename': 'openstreetmap', 'attribution':...     1429
# 7   {'sourcename': 'openstreetmap', 'attribution':...     1718
# 8   {'sourcename': 'openstreetmap', 'attribution':...     1851
# 9   {'sourcename': 'openstreetmap', 'attribution':...     1890
# 10  {'sourcename': 'openstreetmap', 'attribution':...     2221
# 11  {'sourcename': 'openstreetmap', 'attribution':...     2273
# 12  {'sourcename': 'openstreetmap', 'attribution':...     2372
# 13  {'sourcename': 'openstreetmap', 'attribution':...     2881
# 14  {'sourcename': 'openstreetmap', 'attribution':...     3355
# 15  {'sourcename': 'openstreetmap', 'attribution':...     3365
# 16  {'sourcename': 'openstreetmap', 'attribution':...     3450
# 17  {'sourcename': 'openstreetmap', 'attribution':...     3528
# 18  {'sourcename': 'openstreetmap', 'attribution':...     3617
# 19  {'sourcename': 'openstreetmap', 'attribution':...     3692
#
#                                              place_id  \
# 0   51f13692909e9d5dc05993c3ee31a40a4140f00102f901...
# 1   51216937fa989d5dc059816f71af820a4140f00103f901...
# 2   515673ac9f029e5dc05919a10a0e96084140f00102f901...
# 3   5116061022aa9d5dc0595e05b1ae2c0b4140f00102f901...
# 4   515b7b0a0bdd9d5dc059b6a2bf8563084140f00102f901...
# 5   5103194ba2a89d5dc05983b844f5310b4140f00103f901...
# 6   511d01dc2cde9e5dc0597ee1bcffea0a4140f00103f901...
# 7   513be3fbe2529e5dc059ff7fc0cafc074140f00103f901...
# 8   5114e3081b4c9f5dc05969f0997a07094140f00102f901...
# 9   51731838456c9e5dc059fcb6b7c7d2074140f00103f901...
# 10  5178a714567f9c5dc05932238d72a6094140f00102f901...
# 11  51479038f77f9c5dc0592a3616519c094140f00102f901...
# 12  5115cf58a8659c5dc0598dc9c5dbab094140f00102f901...
# 13  51ec9df035599e5dc0599fb7443382064140f00102f901...
# 14  51a302dd4da69f5dc059239a9ca113074140f00103f901...
# 15  51d385d4f3c29b5dc059ea285592e5084140f00102f901...
# 16  5108273c28c39b5dc0598259c6bb550b4140f00102f901...
# 17  51c8843036699d5dc059dc11588dc6054140f00102f901...
# 18  51c19f100a239d5dc059459b553002064140f00102f901...
# 19  514c23ab7f9f9d5dc0598d5fff11a5054140f00102f901...
#
#                                              name           district  \
# 0                                             NaN                NaN
# 1                        Bellagio Newcomer Center                NaN
# 2                    Brentwood School East Campus  Brentwood Heights
# 3                                             NaN                NaN
# 4   Brentwood School Athletic Facilities VA lease  Brentwood Heights
# 5                      The John Thomas Dye School                NaN
# 6      Mount Saint Mary's College - Chalon Campus                NaN
# 7                    Saint Martin of Tours School  Brentwood Heights
# 8                 Kenter Canyon Elementary School                NaN
# 9                         Marymount Junior School  Brentwood Heights
# 10                                            NaN                NaN
# 11                          Marymount High School                NaN
# 12                                UCLA Lab School                NaN
# 13                Brentwood Science Magnet School           Westgate
# 14                           Revere Middle School     Brentwood Park
# 15                       Warner Elementary School       Holmby Hills
# 16                 Harvard-Westlake Middle School                NaN
# 17                         University High School                NaN
# 18                         Saint Sebastian School                NaN
# 19              Brockton Avenue Elementary School                NaN
#
#        suburb  quarter housenumber  \
# 0         NaN      NaN         NaN
# 1         NaN      NaN         NaN
# 2   Brentwood      NaN         NaN
# 3         NaN      NaN         NaN
# 4   Brentwood      NaN         NaN
# 5         NaN      NaN         NaN
# 6         NaN      NaN         NaN
# 7   Brentwood      NaN         NaN
# 8         NaN      NaN         NaN
# 9   Brentwood      NaN         NaN
# 10   Westwood  Bel Air         NaN
# 11   Westwood      NaN       10643
# 12   Westwood  Bel Air         NaN
# 13  Brentwood      NaN         NaN
# 14        NaN      NaN         NaN
# 15   Westwood      NaN         NaN
# 16        NaN      NaN         NaN
# 17   Sawtelle      NaN         NaN
# 18   Sawtelle      NaN         NaN
# 19   Sawtelle      NaN         NaN
#
#                                          old_name           city
# 0                                             NaN            NaN
# 1                                             NaN            NaN
# 2                                             NaN            NaN
# 3                                             NaN            NaN
# 4                                             NaN            NaN
# 5                                             NaN            NaN
# 6                                             NaN            NaN
# 7                                             NaN            NaN
# 8                                             NaN            NaN
# 9                                             NaN            NaN
# 10                                            NaN            NaN
# 11                                            NaN            NaN
# 12  Corinne A. Seeds University Elementary School            NaN
# 13                                            NaN            NaN
# 14                                            NaN            NaN
# 15                                            NaN            NaN
# 16                                            NaN  Beverly Hills
# 17                                            NaN            NaN
# 18                                            NaN            NaN
# 19                                            NaN            NaN
#
# [20 rows x 24 columns]

# %%
print(df.columns)
# Out:
# Index(['country', 'country_code', 'state', 'county', 'postcode', 'street',
#        'lon', 'lat', 'state_code', 'formatted', 'address_line1',
#        'address_line2', 'categories', 'details', 'datasource', 'distance',
#        'place_id', 'name', 'district', 'suburb', 'quarter', 'housenumber',
#        'old_name', 'city'],
#       dtype='object')

# %%
df = df.dropna(subset=['name', 'postcode'])
df = df.drop(columns=['country','country_code','state','street','lon','lat','state_code','formatted','address_line1',
                     'address_line2','categories','details','datasource','place_id','housenumber','district','suburb',
                      'quarter','old_name','city'])
df = df.rename(columns={
    'properties.postcode': 'zip_code',
    'properties.distance': 'distance',
})
df
# Out:
#                 county postcode  distance  \
# 1   Los Angeles County    90049       855
# 2   Los Angeles County    90049      1074
# 4   Los Angeles County    90049      1129
# 5   Los Angeles County    90049      1253
# 6   Los Angeles County    90049      1429
# 7   Los Angeles County    90049      1718
# 8   Los Angeles County    90272      1851
# 9   Los Angeles County    90272      1890
# 11  Los Angeles County    90077      2273
# 12  Los Angeles County    90095      2372
# 13  Los Angeles County    90073      2881
# 14  Los Angeles County    90272      3355
# 15  Los Angeles County    90095      3365
# 16  Los Angeles County    90077      3450
# 17  Los Angeles County    90073      3528
# 18  Los Angeles County    90064      3617
# 19  Los Angeles County    90025      3692
#
#                                              name
# 1                        Bellagio Newcomer Center
# 2                    Brentwood School East Campus
# 4   Brentwood School Athletic Facilities VA lease
# 5                      The John Thomas Dye School
# 6      Mount Saint Mary's College - Chalon Campus
# 7                    Saint Martin of Tours School
# 8                 Kenter Canyon Elementary School
# 9                         Marymount Junior School
# 11                          Marymount High School
# 12                                UCLA Lab School
# 13                Brentwood Science Magnet School
# 14                           Revere Middle School
# 15                       Warner Elementary School
# 16                 Harvard-Westlake Middle School
# 17                         University High School
# 18                         Saint Sebastian School
# 19              Brockton Avenue Elementary School
