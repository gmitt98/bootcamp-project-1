# %%
# Dependencies
import requests
import json
from pprint import pprint
import pandas as pd
import hvplot.pandas

# Import the API key
from config import geoapify_key

# %%
zipcode = "97214" #insert zipcode of choice

params = {
    "apiKey": geoapify_key,
    "country":"United States",
    "postcode": zipcode
}
# Build URL using the geocode endpoint
base_url = f"https://api.geoapify.com/v1/geocode/search?text={zipcode}&lang=en&type=postcode&filter=countrycode:us"

# %%
#run request
response = requests.get(base_url, params=params).json()

# %%
 # Extract lat/lon
lat = response["features"][0]["properties"]["lat"]
lon = response["features"][0]["properties"]["lon"]
place_id = response["features"][0]["properties"]["place_id"]

# %%
# Set paramaters for type of place
categories = "leisure.park"

# Set parameters for type of search
bias = f"proximity:{lon},{lat}"
filters = f"place:{place_id}"

# %%
#parameters dictionary
params = {
    "categories": categories,
    "bias": bias,
    "filters":filters,
    "apiKey": geoapify_key    
}

# %%
# Set base URL
base_url = f"https://api.geoapify.com/v2/places?"

# %%
response = requests.get(base_url, params=params).json()

# %%
# Extract the features list from the dictionary
features_list = response['features']

# Extract the relevant properties from each feature
rows = []
for feature in features_list:
    properties = feature['properties']
    rows.append(properties)

# Create a DataFrame from the list of dictionaries
df = pd.DataFrame(rows)
df
# Out:
#                                 name        country country_code   state  \
# 0       Sewallcrest Community Garden  United States           us  Oregon
# 1   Colonel Summers Community Garden  United States           us  Oregon
# 2               Colonel Summers Park  United States           us  Oregon
# 3                   Sewallcrest Park  United States           us  Oregon
# 4              Sunnyside School Park  United States           us  Oregon
# 5             Blair Community Garden  United States           us  Oregon
# 6                   Ladd East Garden  United States           us  Oregon
# 7                   Laurelhurst Park  United States           us  Oregon
# 8                  Ladd North Garden  United States           us  Oregon
# 9           Buckman Community Garden  United States           us  Oregon
# 10                       Ladd Circle  United States           us  Oregon
# 11                             Kerns  United States           us  Oregon
# 12                      Piccolo Park  United States           us  Oregon
# 13        Washington Monroe Property  United States           us  Oregon
# 14          Everett Community Garden  United States           us  Oregon
# 15                             Kerns  United States           us  Oregon
# 16                 Ladd South Garden  United States           us  Oregon
# 17                  Ladd West Garden  United States           us  Oregon
# 18                             Kerns  United States           us  Oregon
# 19          Clinton Community Garden  United States           us  Oregon
#
#               county      city postcode          district             suburb  \
# 0   Multnomah County  Portland    97214  Colonial Heights           Richmond
# 1   Multnomah County  Portland    97214               NaN            Buckman
# 2   Multnomah County  Portland      NaN               NaN            Buckman
# 3   Multnomah County  Portland      NaN  Colonial Heights           Richmond
# 4   Multnomah County  Portland      NaN           Belmont          Sunnyside
# 5   Multnomah County  Portland    97214           Belmont          Sunnyside
# 6   Multnomah County  Portland    97214               NaN  Hosford-Abernethy
# 7   Multnomah County  Portland      NaN               NaN        Laurelhurst
# 8   Multnomah County  Portland    97214               NaN  Hosford-Abernethy
# 9   Multnomah County  Portland    97214               NaN            Buckman
# 10  Multnomah County  Portland      NaN               NaN  Hosford-Abernethy
# 11  Multnomah County  Portland      NaN               NaN              Kerns
# 12  Multnomah County  Portland      NaN               NaN  Hosford-Abernethy
# 13  Multnomah County  Portland      NaN               NaN            Buckman
# 14  Multnomah County  Portland    97232               NaN              Kerns
# 15  Multnomah County  Portland      NaN               NaN              Kerns
# 16  Multnomah County  Portland    97214               NaN  Hosford-Abernethy
# 17  Multnomah County  Portland    97214               NaN  Hosford-Abernethy
# 18  Multnomah County  Portland      NaN               NaN              Kerns
# 19  Multnomah County  Portland    97214               NaN  Hosford-Abernethy
#
#                        street  ...  \
# 0     Southeast Market Street  ...
# 1     Southeast Taylor Street  ...
# 2                         NaN  ...
# 3                         NaN  ...
# 4                         NaN  ...
# 5       Southeast Alder Court  ...
# 6   Southeast Harrison Street  ...
# 7                         NaN  ...
# 8       Southeast 16th Avenue  ...
# 9        Southeast Oak Street  ...
# 10                        NaN  ...
# 11                        NaN  ...
# 12                        NaN  ...
# 13                        NaN  ...
# 14   Northeast Everett Street  ...
# 15                        NaN  ...
# 16      Southeast 16th Avenue  ...
# 17    Southeast Spruce Avenue  ...
# 18                        NaN  ...
# 19   Southeast Clinton Street  ...
#
#                                             formatted  \
# 0   Sewallcrest Community Garden, Southeast Market...
# 1   Colonel Summers Community Garden, Southeast Ta...
# 2   Colonel Summers Park, Buckman, Portland, OR, U...
# 3   Sewallcrest Park, Richmond, Portland, OR, Unit...
# 4   Sunnyside School Park, Sunnyside, Portland, OR...
# 5   Blair Community Garden, Southeast Alder Court,...
# 6   Ladd East Garden, Southeast Harrison Street, P...
# 7   Laurelhurst Park, Laurelhurst, Portland, OR, U...
# 8   Ladd North Garden, Southeast 16th Avenue, Port...
# 9   Buckman Community Garden, Southeast Oak Street...
# 10  Ladd Circle, Hosford-Abernethy, Portland, OR, ...
# 11      Kerns, Portland, OR, United States of America
# 12  Piccolo Park, Hosford-Abernethy, Portland, OR,...
# 13  Washington Monroe Property, Buckman, Portland,...
# 14  Everett Community Garden, Northeast Everett St...
# 15      Kerns, Portland, OR, United States of America
# 16  Ladd South Garden, Southeast 16th Avenue, Port...
# 17  Ladd West Garden, Southeast Spruce Avenue, Por...
# 18      Kerns, Portland, OR, United States of America
# 19  Clinton Community Garden, Southeast Clinton St...
#
#                        address_line1  \
# 0       Sewallcrest Community Garden
# 1   Colonel Summers Community Garden
# 2               Colonel Summers Park
# 3                   Sewallcrest Park
# 4              Sunnyside School Park
# 5             Blair Community Garden
# 6                   Ladd East Garden
# 7                   Laurelhurst Park
# 8                  Ladd North Garden
# 9           Buckman Community Garden
# 10                       Ladd Circle
# 11                             Kerns
# 12                      Piccolo Park
# 13        Washington Monroe Property
# 14          Everett Community Garden
# 15                             Kerns
# 16                 Ladd South Garden
# 17                  Ladd West Garden
# 18                             Kerns
# 19          Clinton Community Garden
#
#                                         address_line2  \
# 0   Southeast Market Street, Portland, OR 97214, U...
# 1   Southeast Taylor Street, Portland, OR 97214, U...
# 2     Buckman, Portland, OR, United States of America
# 3    Richmond, Portland, OR, United States of America
# 4   Sunnyside, Portland, OR, United States of America
# 5   Southeast Alder Court, Portland, OR 97214, Uni...
# 6   Southeast Harrison Street, Portland, OR 97214,...
# 7   Laurelhurst, Portland, OR, United States of Am...
# 8   Southeast 16th Avenue, Portland, OR 97214, Uni...
# 9   Southeast Oak Street, Portland, OR 97214, Unit...
# 10  Hosford-Abernethy, Portland, OR, United States...
# 11             Portland, OR, United States of America
# 12  Hosford-Abernethy, Portland, OR, United States...
# 13    Buckman, Portland, OR, United States of America
# 14  Northeast Everett Street, Portland, OR 97232, ...
# 15             Portland, OR, United States of America
# 16  Southeast 16th Avenue, Portland, OR 97214, Uni...
# 17  Southeast Spruce Avenue, Portland, OR 97214, U...
# 18             Portland, OR, United States of America
# 19  Southeast Clinton Street, Portland, OR 97214, ...
#
#                                            categories  \
# 0   [access_limited, access_limited.with_permit, l...
# 1        [leisure, leisure.park, leisure.park.garden]
# 2                             [leisure, leisure.park]
# 3                             [leisure, leisure.park]
# 4         [access, access.yes, leisure, leisure.park]
# 5   [access_limited, access_limited.with_permit, l...
# 6        [leisure, leisure.park, leisure.park.garden]
# 7   [heritage, leisure, leisure.park, tourism, tou...
# 8        [leisure, leisure.park, leisure.park.garden]
# 9   [access_limited, access_limited.with_permit, l...
# 10                            [leisure, leisure.park]
# 11                            [leisure, leisure.park]
# 12                            [leisure, leisure.park]
# 13                            [leisure, leisure.park]
# 14  [access_limited, access_limited.with_permit, l...
# 15                            [leisure, leisure.park]
# 16       [leisure, leisure.park, leisure.park.garden]
# 17       [leisure, leisure.park, leisure.park.garden]
# 18                            [leisure, leisure.park]
# 19  [access_limited, access_limited.with_permit, l...
#
#                                               details  \
# 0                                           [details]
# 1                                           [details]
# 2                   [details, details.wiki_and_media]
# 3                   [details, details.wiki_and_media]
# 4                   [details, details.wiki_and_media]
# 5                                           [details]
# 6                   [details, details.wiki_and_media]
# 7   [details, details.heritage, details.historic, ...
# 8                   [details, details.wiki_and_media]
# 9                                           [details]
# 10                  [details, details.wiki_and_media]
# 11                                                 []
# 12                                          [details]
# 13                                          [details]
# 14                                          [details]
# 15                                                 []
# 16                  [details, details.wiki_and_media]
# 17                  [details, details.wiki_and_media]
# 18                                                 []
# 19                                          [details]
#
#                                            datasource distance  \
# 0   {'sourcename': 'openstreetmap', 'attribution':...      559
# 1   {'sourcename': 'openstreetmap', 'attribution':...      563
# 2   {'sourcename': 'openstreetmap', 'attribution':...      576
# 3   {'sourcename': 'openstreetmap', 'attribution':...      584
# 4   {'sourcename': 'openstreetmap', 'attribution':...      718
# 5   {'sourcename': 'openstreetmap', 'attribution':...      737
# 6   {'sourcename': 'openstreetmap', 'attribution':...      908
# 7   {'sourcename': 'openstreetmap', 'attribution':...      918
# 8   {'sourcename': 'openstreetmap', 'attribution':...      927
# 9   {'sourcename': 'openstreetmap', 'attribution':...      964
# 10  {'sourcename': 'openstreetmap', 'attribution':...     1019
# 11  {'sourcename': 'openstreetmap', 'attribution':...     1051
# 12  {'sourcename': 'openstreetmap', 'attribution':...     1101
# 13  {'sourcename': 'openstreetmap', 'attribution':...     1104
# 14  {'sourcename': 'openstreetmap', 'attribution':...     1126
# 15  {'sourcename': 'openstreetmap', 'attribution':...     1147
# 16  {'sourcename': 'openstreetmap', 'attribution':...     1166
# 17  {'sourcename': 'openstreetmap', 'attribution':...     1171
# 18  {'sourcename': 'openstreetmap', 'attribution':...     1211
# 19  {'sourcename': 'openstreetmap', 'attribution':...     1313
#
#                                              place_id           quarter  \
# 0   5182b51a9886a85ec059ddfebf4257c14640f00102f901...               NaN
# 1   518ead43da56a95ec059a87c65b1fcc14640f00102f901...  Central Eastside
# 2   519de0b2cb69a95ec0597cf8606902c24640f00102f901...               NaN
# 3   513f0bbaf981a85ec059d9d1e3743ac14640f00102f901...               NaN
# 4   51939720373fa85ec059dade78bbf5c14640f00102f901...               NaN
# 5   51f42772e067a85ec0594585582d6ac24640f00102f901...               NaN
# 6   5164dafc706da95ec0590be6a3cc17c14640f00102f901...   Ladd's Addition
# 7   5197e63fcd12a85ec0595042aff0b1c24640f00102f901...               NaN
# 8   51eb6d050690a95ec059fea4ab3253c14640f00102f901...   Ladd's Addition
# 9   516eafb9de79a95ec0590498953c92c24640f00102f901...               NaN
# 10  5154cf551f90a95ec05966cb6bfd17c14640f00102f901...   Ladd's Addition
# 11  517d370ddaf6a85ec0595e76a7fc10c34640f00102f901...               NaN
# 12  513a273d55d6a85ec059d4aed73586c04640f00102f901...               NaN
# 13  5146294b44c5a95ec05994c2d90a5ec24640f00102f901...  Central Eastside
# 14  51a854fa1cdda85ec059eb5e103327c34640f00102f901...               NaN
# 15  5168f63473e5a85ec05967a0217f2ac34640f00102f901...               NaN
# 16  5148fa542d90a95ec059e55d219ddcc04640f00102f901...   Ladd's Addition
# 17  516b6082bdb2a95ec059d93cdb0118c14640f00102f901...   Ladd's Addition
# 18  511d6341b16ca95ec0591392ed28ffc24640f00102f901...               NaN
# 19  518a0c175e6ea95ec059badc56ca7cc04640f00102f901...   Ladd's Addition
#
#            old_name
# 0               NaN
# 1               NaN
# 2      Belmont Park
# 3               NaN
# 4               NaN
# 5               NaN
# 6               NaN
# 7   Hazel Fern Farm
# 8               NaN
# 9               NaN
# 10              NaN
# 11              NaN
# 12              NaN
# 13              NaN
# 14              NaN
# 15              NaN
# 16              NaN
# 17              NaN
# 18              NaN
# 19              NaN
#
# [20 rows x 23 columns]

# %%
df = df.dropna(subset=['name', 'postcode'])
df = df.drop(columns=['country','country_code','state','street','state_code','formatted','address_line1',
                     'address_line2','categories','details','datasource','place_id','housenumber','district','suburb',
                      'quarter','old_name','city','hamlet'],errors='ignore')
df = df.rename(columns={'postcode': 'zipcode'})
df
# Out:
#                                 name            county zipcode         lon  \
# 0       Sewallcrest Community Garden  Multnomah County   97214 -122.633155
# 1   Colonel Summers Community Garden  Multnomah County   97214 -122.645941
# 5             Blair Community Garden  Multnomah County   97214 -122.631479
# 6                   Ladd East Garden  Multnomah County   97214 -122.647305
# 8                  Ladd North Garden  Multnomah County   97214 -122.649416
# 9           Buckman Community Garden  Multnomah County   97214 -122.648067
# 14          Everett Community Garden  Multnomah County   97232 -122.638494
# 16                 Ladd South Garden  Multnomah County   97214 -122.649425
# 17                  Ladd West Garden  Multnomah County   97214 -122.651535
# 19          Clinton Community Garden  Multnomah County   97214 -122.647361
#
#           lat  distance
# 0   45.510604       559
# 1   45.515528       563
# 5   45.518766       737
# 6   45.508539       908
# 8   45.510352       927
# 9   45.520089       964
# 14  45.524702      1126
# 16  45.506733      1166
# 17  45.508545      1171
# 19  45.503808      1313

# %%
area_df = df
zip_df = area_df.loc[area_df['zipcode'] == zipcode]

# %%
area_df
# Out:
#                                 name            county zipcode         lon  \
# 0       Sewallcrest Community Garden  Multnomah County   97214 -122.633155
# 1   Colonel Summers Community Garden  Multnomah County   97214 -122.645941
# 5             Blair Community Garden  Multnomah County   97214 -122.631479
# 6                   Ladd East Garden  Multnomah County   97214 -122.647305
# 8                  Ladd North Garden  Multnomah County   97214 -122.649416
# 9           Buckman Community Garden  Multnomah County   97214 -122.648067
# 14          Everett Community Garden  Multnomah County   97232 -122.638494
# 16                 Ladd South Garden  Multnomah County   97214 -122.649425
# 17                  Ladd West Garden  Multnomah County   97214 -122.651535
# 19          Clinton Community Garden  Multnomah County   97214 -122.647361
#
#           lat  distance
# 0   45.510604       559
# 1   45.515528       563
# 5   45.518766       737
# 6   45.508539       908
# 8   45.510352       927
# 9   45.520089       964
# 14  45.524702      1126
# 16  45.506733      1166
# 17  45.508545      1171
# 19  45.503808      1313

# %%
zip_df
# Out:
#                                 name            county zipcode         lon  \
# 0       Sewallcrest Community Garden  Multnomah County   97214 -122.633155
# 1   Colonel Summers Community Garden  Multnomah County   97214 -122.645941
# 5             Blair Community Garden  Multnomah County   97214 -122.631479
# 6                   Ladd East Garden  Multnomah County   97214 -122.647305
# 8                  Ladd North Garden  Multnomah County   97214 -122.649416
# 9           Buckman Community Garden  Multnomah County   97214 -122.648067
# 16                 Ladd South Garden  Multnomah County   97214 -122.649425
# 17                  Ladd West Garden  Multnomah County   97214 -122.651535
# 19          Clinton Community Garden  Multnomah County   97214 -122.647361
#
#           lat  distance
# 0   45.510604       559
# 1   45.515528       563
# 5   45.518766       737
# 6   45.508539       908
# 8   45.510352       927
# 9   45.520089       964
# 16  45.506733      1166
# 17  45.508545      1171
# 19  45.503808      1313

# %%
parkmapOR = zip_df.hvplot.points('lon', 'lat', geo=True, frame_width = 800, frame_height = 600, hover_cols=['name', 'zipcode'],
                                 tiles='OSM', color='blue', title = "Parks in Multnomah County")
parkmapOR
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [lon,lat]   (name,zipcode)
